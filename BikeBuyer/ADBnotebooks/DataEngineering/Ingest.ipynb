# %% [markdown]
# # Data Ingestion

# %%
# Download adworks-bike-purchases.csv from GitHub. This file has 9133 rows.
import os
import urllib

basedataurl = "https://raw.githubusercontent.com/DataSnowman/MLonBigData/master/BikeBuyer/LoyaltyCardBuyers"
datafile = "adworks-bike-purchases.csv"
datafile_dbfs = os.path.join("/dbfs", datafile)

if os.path.isfile(datafile_dbfs):
    print("found {} at {}".format(datafile, datafile_dbfs))
else:
    print("downloading {} to {}".format(datafile, datafile_dbfs))
    urllib.request.urlretrieve(os.path.join(basedataurl, datafile), datafile_dbfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">downloading adworks-bike-purchases.csv to /dbfs/adworks-bike-purchases.csv
# </div>

# %%
# %sh
cat /dbfs/adworks-bike-purchases.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">﻿LoyaltyCardID,Region,Age,Bikes
# 11417,Europe,68,7
# 11241,Europe,44,7
# 11420,Europe,66,7
# 11242,Europe,55,7
# 11429,Europe,60,6
# 11439,Europe,64,6
# 11425,Europe,53,6
# 11433,Europe,61,6
# 11432,Europe,61,6
# 12300,Europe,66,5
# 12321,Europe,62,5
# 12132,Europe,57,5
# 12308,Europe,48,5
# 12296,Europe,57,5
# 12124,Europe,56,5
# 12307,Europe,58,5
# 12131,Europe,57,5
# 12301,Europe,66,5
# 12333,Europe,64,4
# 14192,Europe,62,4
# 13606,Europe,63,4
# 12291,Europe,69,4
# 13260,Europe,55,4
# 11428,Europe,59,4
# 11244,Europe,49,4
# 12631,Europe,68,4
# 13261,Europe,56,4
# 13263,Europe,57,4
# 11423,Europe,58,4
# 11414,Europe,59,4
# 11245,Europe,56,4
# 13592,Europe,55,4
# 13256,Europe,55,4
# 12130,Europe,56,4
# 12128,Europe,50,4
# 11422,Europe,66,4
# 13259,Europe,55,4
# 11431,Europe,44,4
# 12125,Europe,56,4
# 12632,Europe,57,4
# 12657,Europe,63,4
# 14186,Europe,60,4
# 13264,Europe,56,4
# 12123,Europe,54,4
# 12650,Europe,63,4
# 12332,Europe,64,4
# 14185,Europe,60,4
# 11427,Europe,59,4
# 11239,Europe,49,4
# 11238,Europe,54,4
# 11249,Europe,52,4
# 11413,Europe,59,4
# 11243,Europe,55,4
# 13579,Europe,61,4
# 13405,Europe,55,4
# 11421,Europe,66,4
# 13255,Europe,56,4
# 12655,Europe,64,4
# 12129,Europe,56,4
# 13575,Europe,68,4
# 13257,Europe,55,4
# 13265,Europe,57,4
# 11237,Europe,54,4
# 11247,Europe,56,4
# 12330,Europe,63,4
# 14200,Europe,64,4
# 12314,Europe,59,4
# 12323,Europe,56,4
# 12298,Europe,67,4
# 11412,Europe,59,4
# 11250,Europe,52,4
# 13605,Europe,63,4
# 13258,Europe,56,4
# 11246,Europe,56,4
# 12302,Europe,67,4
# 12297,Europe,68,4
# 13580,Europe,66,4
# 13577,Europe,67,4
# 11240,Europe,54,4
# 12133,Europe,57,4
# 13595,Europe,61,4
# 13406,Europe,56,4
# 12305,Europe,58,3
# 15632,Europe,42,3
# 16594,Europe,61,3
# 12316,Europe,53,3
# 11027,Pacific,66,3
# 13632,Pacific,41,3
# 11930,Pacific,65,3
# 13823,Europe,45,3
# 13407,Europe,55,3
# 18125,Europe,43,3
# 11754,Pacific,42,3
# 12608,Europe,47,3
# 16567,Europe,43,3
# 13953,Pacific,38,3
# 13633,Pacific,41,3
# 12342,Pacific,38,3
# 16393,Europe,33,3
# 11025,Pacific,67,3
# 11191,North America,67,3
# 13139,Pacific,51,3
# 12620,Europe,44,3
# 16565,Europe,44,3
# 14697,Europe,41,3
# 13971,Pacific,44,3
# 12283,Europe,38,3
# 13079,Pacific,56,3
# 11460,Pacific,35,3
# 13038,Pacific,57,3
# 17779,Europe,44,3
# 12619,Europe,43,3
# 13106,Pacific,45,3
# 12459,Europe,44,3
# 15085,Europe,43,3
# 13631,Pacific,40,3
# 11756,Pacific,44,3
# 11944,Pacific,62,3
# 11479,Europe,40,3
# 12687,Pacific,41,3
# 14211,Pacific,32,3
# 11759,Pacific,37,3
# 16045,Europe,49,3
# 13626,Pacific,34,3
# 12668,Pacific,37,3
# 15086,Europe,38,3
# 13782,Europe,40,3
# 13076,Pacific,58,3
# 17834,Europe,50,3
# 14261,Pacific,60,3
# 14847,Europe,39,3
# 14146,Europe,53,3
# 15631,Europe,41,3
# 11039,Pacific,64,3
# 11447,Pacific,38,3
# 11047,Pacific,63,3
# 20861,Europe,43,3
# 12384,Europe,39,3
# 11988,Pacific,50,3
# 13012,Pacific,47,3
# 12360,Pacific,41,3
# 13602,Europe,62,3
# 11070,Pacific,58,3
# 11090,North America,49,3
# 16603,Europe,65,3
# 11992,Pacific,46,3
# 11360,Pacific,34,3
# 11126,Pacific,64,3
# 11353,Europe,71,3
# 14238,Pacific,42,3
# 15933,Europe,52,3
# 11462,Pacific,41,3
# 19476,Europe,41,3
# 17185,Europe,55,3
# 11968,Pacific,54,3
# 12216,Europe,51,3
# 11550,Europe,39,3
# 17648,Europe,42,3
# 11496,Europe,42,3
# 14666,Pacific,38,3
# 13685,Europe,34,3
# 11095,Pacific,50,3
# 12000,Pacific,48,3
# 11046,Pacific,63,3
# 17986,Europe,40,3
# 13960,Pacific,45,3
# 16821,Europe,54,3
# 14305,Pacific,50,3
# 12355,Pacific,34,3
# 15116,Europe,57,3
# 17825,Europe,49,3
# 17767,Europe,43,3
# 15923,Europe,51,3
# 13114,Pacific,46,3
# 17221,Europe,63,3
# 11993,Pacific,41,3
# 12003,Pacific,39,3
# 13607,Europe,58,3
# 15094,Europe,63,3
# 14071,Pacific,54,3
# 16425,Europe,47,3
# 19325,Europe,46,3
# 12807,Europe,44,3
# 16261,Europe,34,3
# 15695,Europe,58,3
# 11344,Europe,55,3
# 13408,Europe,56,3
# 14162,Europe,43,3
# 15080,Europe,32,3
# 15932,Europe,57,3
# 11488,Europe,41,3
# 12210,Europe,34,3
# 13133,Pacific,53,3
# 18133,Europe,40,3
# 11099,Pacific,52,3
# 11964,Pacific,51,3
# 12999,Pacific,45,3
# 13964,Pacific,47,3
# 15129,Pacific,34,3
# 13590,Europe,59,3
# 13132,Pacific,54,3
# 12705,Pacific,38,3
# 12289,Europe,34,3
# 14058,Pacific,42,3
# 14207,Europe,65,3
# 14702,Europe,40,3
# 11017,Pacific,68,3
# 20923,Europe,49,3
# 14316,Pacific,51,3
# 14101,Pacific,70,3
# 11453,Pacific,34,3
# 12706,Pacific,38,3
# 13784,Europe,47,3
# 13559,Europe,43,3
# 14937,Europe,35,3
# 11033,Pacific,60,3
# 14326,Pacific,56,3
# 15056,Europe,54,3
# 14940,Europe,40,3
# 17781,Europe,45,3
# 12995,Pacific,42,3
# 12398,Europe,41,3
# 11904,Pacific,32,3
# 11493,Europe,42,3
# 12215,Europe,50,3
# 11908,Pacific,46,3
# 15117,Europe,63,3
# 19340,Europe,47,3
# 12703,Pacific,41,3
# 11489,Europe,42,3
# 16830,Europe,57,3
# 12381,Europe,33,3
# 12390,Europe,35,3
# 11994,Pacific,41,3
# 14236,Pacific,36,3
# 13105,Pacific,50,3
# 13591,Europe,54,3
# 17811,Europe,46,3
# 11610,Europe,38,3
# 11575,Europe,48,3
# 13697,Europe,41,3
# 11058,Pacific,53,3
# 13119,Pacific,47,3
# 13770,Europe,44,3
# 11096,Pacific,50,3
# 11031,Pacific,65,3
# 12989,Pacific,43,3
# 11766,Pacific,46,3
# 14791,Europe,45,3
# 11900,Pacific,37,3
# 16448,Europe,51,3
# 15661,Europe,53,3
# 14843,Europe,37,3
# 13765,Europe,44,3
# 15662,Europe,52,3
# 11009,Pacific,49,3
# 13600,Europe,62,3
# 12339,Pacific,36,3
# 11929,Pacific,56,3
# 11365,Pacific,33,3
# 13007,Pacific,47,3
# 15925,Europe,56,3
# 17199,Europe,61,3
# 12609,Europe,53,3
# 12382,Europe,34,3
# 11547,Europe,39,3
# 18626,Europe,40,3
# 12397,Europe,43,3
# 14051,Pacific,36,3
# 11568,Europe,46,3
# 16204,Europe,36,3
# 18135,Europe,50,3
# 16298,Europe,49,3
# 14215,Pacific,37,3
# 13115,Pacific,35,3
# 13126,Pacific,49,3
# 11004,Pacific,39,3
# 12287,Europe,61,3
# 18139,Europe,47,3
# 12647,Europe,55,3
# 14830,Europe,44,3
# 16203,Europe,42,3
# 13251,Europe,44,3
# 14991,Europe,37,3
# 14234,Pacific,42,3
# 15677,Europe,43,3
# 11263,North America,48,3
# 11257,North America,80,3
# 12686,Pacific,40,3
# 14716,Europe,36,3
# 16831,Europe,57,3
# 14235,Pacific,37,3
# 11444,Pacific,37,3
# 11105,Pacific,48,3
# 14681,Pacific,39,3
# 14833,Europe,50,3
# 13560,Europe,38,3
# 15062,Europe,52,3
# 14224,Pacific,34,3
# 14950,Europe,43,3
# 13638,Pacific,40,3
# 15122,Pacific,36,3
# 18019,Europe,49,3
# 14048,Pacific,51,3
# 16392,Europe,44,3
# 20722,Europe,41,3
# 12510,Europe,50,3
# 12640,Europe,53,3
# 14181,Europe,66,3
# 11452,Pacific,39,3
# 11069,Pacific,52,3
# 11093,Pacific,40,3
# 11451,Pacific,38,3
# 12634,Europe,67,3
# 12011,Pacific,78,3
# 14020,Pacific,58,3
# 12349,Pacific,38,3
# 15106,Europe,47,3
# 12648,Europe,61,3
# 11029,Pacific,66,3
# 11003,Pacific,45,3
# 17202,Europe,68,3
# 16309,Europe,50,3
# 15678,Europe,38,3
# 11171,North America,40,3
# 13841,Europe,39,3
# 12394,Europe,36,3
# 13581,Europe,66,3
# 12701,Pacific,36,3
# 12738,Europe,39,3
# 19339,Europe,46,3
# 11765,Pacific,35,3
# 13090,Pacific,53,3
# 13777,Europe,45,3
# 12463,Europe,44,3
# 14038,Pacific,53,3
# 15700,Europe,60,3
# 11381,Europe,48,3
# 19364,Europe,45,3
# 13553,Europe,38,3
# 19298,Europe,32,3
# 13253,Europe,43,3
# 13822,Europe,50,3
# 17093,Europe,39,3
# 12272,Europe,53,3
# 11767,Pacific,41,3
# 14047,Pacific,50,3
# 15685,Europe,68,3
# 16822,Europe,54,3
# 11035,Pacific,65,3
# 16206,Europe,41,3
# 11468,Europe,37,3
# 11895,Pacific,43,3
# 13637,Pacific,40,3
# 15121,Pacific,36,3
# 15637,Europe,41,3
# 12670,Pacific,37,3
# 14039,Pacific,48,3
# 14191,Europe,56,3
# 12005,Pacific,45,3
# 15692,Europe,59,3
# 12380,Europe,39,3
# 17983,Europe,45,3
# 11455,Pacific,39,3
# 19453,Europe,40,3
# 12658,Europe,58,3
# 14163,Europe,43,3
# 13112,Pacific,40,3
# 13001,Pacific,43,3
# 11341,Europe,76,3
# 13011,Pacific,47,3
# 11151,Pacific,71,3
# 17182,Europe,54,3
# 13651,Pacific,41,3
# 11080,Pacific,53,3
# 14275,Pacific,58,3
# 17209,Europe,59,3
# 14300,Pacific,46,3
# 13091,Pacific,48,3
# 14324,Pacific,56,3
# 14171,Europe,68,3
# 13111,Pacific,51,3
# 11343,Europe,43,3
# 14299,Pacific,45,3
# 12559,Europe,72,3
# 11990,Pacific,50,3
# 13130,Pacific,48,3
# 11117,Pacific,52,3
# 11459,Pacific,40,3
# 17985,Europe,46,3
# 11461,Pacific,41,3
# 17184,Europe,56,3
# 11464,Pacific,41,3
# 12991,Pacific,39,3
# 14055,Pacific,52,3
# 12684,Pacific,39,3
# 11943,Pacific,64,3
# 14719,Europe,43,3
# 16828,Europe,51,3
# 12623,Europe,60,3
# 12039,Pacific,70,3
# 13690,Europe,41,3
# 12599,Europe,47,3
# 11259,North America,48,3
# 11333,Europe,50,3
# 11388,Europe,53,3
# 11976,Pacific,48,3
# 15058,Europe,47,3
# 13108,Pacific,50,3
# 12673,Pacific,37,3
# 11018,Pacific,63,3
# 11967,Pacific,56,3
# 15691,Europe,58,3
# 15097,Europe,68

# %%
# Create a Spark dataframe out of the csv file.
data_all = sqlContext.read.format('csv').options(header='true', inferSchema='true', ignoreLeadingWhiteSpace='true', ignoreTrailingWhiteSpace='true').load(datafile)
print("({}, {})".format(data_all.count(), len(data_all.columns)))
data_all.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(9132, 4)
# root
# -- LoyaltyCardID: integer (nullable = true)
# -- Region: string (nullable = true)
# -- Age: integer (nullable = true)
# -- Bikes: integer (nullable = true)
#
# </div>

# %%
data_all.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>
# [Row(LoyaltyCardID=11417, Region=&apos;Europe&apos;, Age=68, Bikes=7),
#  Row(LoyaltyCardID=11241, Region=&apos;Europe&apos;, Age=44, Bikes=7),
#  Row(LoyaltyCardID=11420, Region=&apos;Europe&apos;, Age=66, Bikes=7),
#  Row(LoyaltyCardID=11242, Region=&apos;Europe&apos;, Age=55, Bikes=7),
#  Row(LoyaltyCardID=11429, Region=&apos;Europe&apos;, Age=60, Bikes=6)]
# </div>

# %%
display(data_all.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LoyaltyCardID</th><th>Region</th><th>Age</th><th>Bikes</th></tr></thead><tbody><tr><td>11417</td><td>Europe</td><td>68</td><td>7</td></tr><tr><td>11241</td><td>Europe</td><td>44</td><td>7</td></tr><tr><td>11420</td><td>Europe</td><td>66</td><td>7</td></tr><tr><td>11242</td><td>Europe</td><td>55</td><td>7</td></tr><tr><td>11429</td><td>Europe</td><td>60</td><td>6</td></tr></tbody></table></div>
