# %% [markdown]
# # Data Ingestion

# %%
# Download adworks-bike-purchases.csv from GitHub. This file has 9132 rows.
import os
import urllib

basedataurl = "https://raw.githubusercontent.com/DataSnowman/MLonBigData/master/BikeBuyer/LoyaltyCardBuyers"
datafile1 = "adworks-bike-purchases.csv"
datafile_dbfs = os.path.join("/dbfs", datafile1)

if os.path.isfile(datafile_dbfs):
    print("found {} at {}".format(datafile1, datafile_dbfs))
else:
    print("downloading {} to {}".format(datafile1, datafile_dbfs))
    urllib.request.urlretrieve(os.path.join(basedataurl, datafile1), datafile_dbfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">found adworks-bike-purchases.csv at /dbfs/adworks-bike-purchases.csv
# </div>

# %%
# Download potential-bike-buyers.csv from GitHub. This file has 18484 rows.
import os
import urllib

basedataurl = "https://raw.githubusercontent.com/DataSnowman/MLonBigData/master/BikeBuyer/LoyaltyCardBuyers"
datafile2 = "potential-bike-buyers.csv"
datafile_dbfs = os.path.join("/dbfs", datafile2)

if os.path.isfile(datafile_dbfs):
    print("found {} at {}".format(datafile2, datafile_dbfs))
else:
    print("downloading {} to {}".format(datafile2, datafile_dbfs))
    urllib.request.urlretrieve(os.path.join(basedataurl, datafile2), datafile_dbfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">found potential-bike-buyers.csv at /dbfs/potential-bike-buyers.csv
# </div>

# %%
# %sh
ls /dbfs/*.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/AdultCensusIncome.csv
# /dbfs/adworks-bike-purchases.csv
# /dbfs/data-scientist-model.csv
# /dbfs/potential-bike-buyers.csv
# </div>

# %%
# Create a Spark dataframe out of the adworks-bike-purchases.csv file.
data_purchases_all = sqlContext.read.format('csv').options(header='true', inferSchema='true', ignoreLeadingWhiteSpace='true', ignoreTrailingWhiteSpace='true').load(datafile1)
print("({}, {})".format(data_purchases_all.count(), len(data_purchases_all.columns)))
data_purchases_all.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(9132, 4)
# root
# -- LoyaltyCardID: integer (nullable = true)
# -- Region: string (nullable = true)
# -- Age: integer (nullable = true)
# -- Bikes: integer (nullable = true)
#
# </div>

# %%
# Create a Spark dataframe out of the potential-bike-buyers.csv file.
data_potential_all = sqlContext.read.format('csv').options(header='true', inferSchema='true', ignoreLeadingWhiteSpace='true', ignoreTrailingWhiteSpace='true').load(datafile2)
print("({}, {})".format(data_potential_all.count(), len(data_potential_all.columns)))
data_potential_all.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(18484, 21)
# root
# -- LoyaltyCardID: integer (nullable = true)
# -- Region: string (nullable = true)
# -- FirstName: string (nullable = true)
# -- MiddleName: string (nullable = true)
# -- LastName: string (nullable = true)
# -- BirthDate: timestamp (nullable = true)
# -- MaritalStatus: string (nullable = true)
# -- Gender: string (nullable = true)
# -- EmailAddress: string (nullable = true)
# -- YearlyIncome: double (nullable = true)
# -- TotalChildren: integer (nullable = true)
# -- NumberChildrenAtHome: integer (nullable = true)
# -- Education: string (nullable = true)
# -- Occupation: string (nullable = true)
# -- HouseOwnerFlag: integer (nullable = true)
# -- NumberCarsOwned: integer (nullable = true)
# -- AddressLine1: string (nullable = true)
# -- AddressLine2: string (nullable = true)
# -- Phone: string (nullable = true)
# -- DateFirstPurchase: timestamp (nullable = true)
# -- CommuteDistance: string (nullable = true)
#
# </div>

# %%
data_purchases_all.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>
# [Row(LoyaltyCardID=11417, Region=&apos;Europe&apos;, Age=68, Bikes=7),
#  Row(LoyaltyCardID=11241, Region=&apos;Europe&apos;, Age=44, Bikes=7),
#  Row(LoyaltyCardID=11420, Region=&apos;Europe&apos;, Age=66, Bikes=7),
#  Row(LoyaltyCardID=11242, Region=&apos;Europe&apos;, Age=55, Bikes=7),
#  Row(LoyaltyCardID=11429, Region=&apos;Europe&apos;, Age=60, Bikes=6)]
# </div>

# %%
data_potential_all.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>
# [Row(LoyaltyCardID=11000, Region=&apos;Australia&apos;, FirstName=&apos;Jon&apos;, MiddleName=&apos;V&apos;, LastName=&apos;Yang&apos;, BirthDate=datetime.datetime(1971, 10, 6, 0, 0), MaritalStatus=&apos;M&apos;, Gender=&apos;M&apos;, EmailAddress=&apos;jon24@adventure-works.com&apos;, YearlyIncome=90000.0, TotalChildren=2, NumberChildrenAtHome=0, Education=&apos;Bachelors&apos;, Occupation=&apos;Professional&apos;, HouseOwnerFlag=1, NumberCarsOwned=0, AddressLine1=&apos;3761 N. 14th St&apos;, AddressLine2=&apos;NULL&apos;, Phone=&apos;1 (11) 500 555-0162&apos;, DateFirstPurchase=datetime.datetime(2011, 1, 19, 0, 0), CommuteDistance=&apos;1-2 Miles&apos;),
#  Row(LoyaltyCardID=11001, Region=&apos;Australia&apos;, FirstName=&apos;Eugene&apos;, MiddleName=&apos;L&apos;, LastName=&apos;Huang&apos;, BirthDate=datetime.datetime(1976, 5, 10, 0, 0), MaritalStatus=&apos;S&apos;, Gender=&apos;M&apos;, EmailAddress=&apos;eugene10@adventure-works.com&apos;, YearlyIncome=60000.0, TotalChildren=3, NumberChildrenAtHome=3, Education=&apos;Bachelors&apos;, Occupation=&apos;Professional&apos;, HouseOwnerFlag=0, NumberCarsOwned=1, AddressLine1=&apos;2243 W St.&apos;, AddressLine2=&apos;NULL&apos;, Phone=&apos;1 (11) 500 555-0110&apos;, DateFirstPurchase=datetime.datetime(2011, 1, 15, 0, 0), CommuteDistance=&apos;0-1 Miles&apos;),
#  Row(LoyaltyCardID=11002, Region=&apos;Australia&apos;, FirstName=&apos;Ruben&apos;, MiddleName=&apos;NULL&apos;, LastName=&apos;Torres&apos;, BirthDate=datetime.datetime(1971, 2, 9, 0, 0), MaritalStatus=&apos;M&apos;, Gender=&apos;M&apos;, EmailAddress=&apos;ruben35@adventure-works.com&apos;, YearlyIncome=60000.0, TotalChildren=3, NumberChildrenAtHome=3, Education=&apos;Bachelors&apos;, Occupation=&apos;Professional&apos;, HouseOwnerFlag=1, NumberCarsOwned=1, AddressLine1=&apos;5844 Linden Land&apos;, AddressLine2=&apos;NULL&apos;, Phone=&apos;1 (11) 500 555-0184&apos;, DateFirstPurchase=datetime.datetime(2011, 1, 7, 0, 0), CommuteDistance=&apos;2-5 Miles&apos;),
#  Row(LoyaltyCardID=11003, Region=&apos;Australia&apos;, FirstName=&apos;Christy&apos;, MiddleName=&apos;NULL&apos;, LastName=&apos;Zhu&apos;, BirthDate=datetime.datetime(1973, 8, 14, 0, 0), MaritalStatus=&apos;S&apos;, Gender=&apos;F&apos;, EmailAddress=&apos;christy12@adventure-works.com&apos;, YearlyIncome=70000.0, TotalChildren=0, NumberChildrenAtHome=0, Education=&apos;Bachelors&apos;, Occupation=&apos;Professional&apos;, HouseOwnerFlag=0, NumberCarsOwned=1, AddressLine1=&apos;1825 Village Pl.&apos;, AddressLine2=&apos;NULL&apos;, Phone=&apos;1 (11) 500 555-0162&apos;, DateFirstPurchase=datetime.datetime(2010, 12, 29, 0, 0), CommuteDistance=&apos;5-10 Miles&apos;),
#  Row(LoyaltyCardID=11004, Region=&apos;Australia&apos;, FirstName=&apos;Elizabeth&apos;, MiddleName=&apos;NULL&apos;, LastName=&apos;Johnson&apos;, BirthDate=datetime.datetime(1979, 8, 5, 0, 0), MaritalStatus=&apos;S&apos;, Gender=&apos;F&apos;, EmailAddress=&apos;elizabeth5@adventure-works.com&apos;, YearlyIncome=80000.0, TotalChildren=5, NumberChildrenAtHome=5, Education=&apos;Bachelors&apos;, Occupation=&apos;Professional&apos;, HouseOwnerFlag=1, NumberCarsOwned=4, AddressLine1=&apos;7553 Harness Circle&apos;, AddressLine2=&apos;NULL&apos;, Phone=&apos;1 (11) 500 555-0131&apos;, DateFirstPurchase=datetime.datetime(2011, 1, 23, 0, 0), CommuteDistance=&apos;1-2 Miles&apos;)]
# </div>

# %%
display(data_purchases_all.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LoyaltyCardID</th><th>Region</th><th>Age</th><th>Bikes</th></tr></thead><tbody><tr><td>11417</td><td>Europe</td><td>68</td><td>7</td></tr><tr><td>11241</td><td>Europe</td><td>44</td><td>7</td></tr><tr><td>11420</td><td>Europe</td><td>66</td><td>7</td></tr><tr><td>11242</td><td>Europe</td><td>55</td><td>7</td></tr><tr><td>11429</td><td>Europe</td><td>60</td><td>6</td></tr></tbody></table></div>

# %%
display(data_potential_all.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LoyaltyCardID</th><th>Region</th><th>FirstName</th><th>MiddleName</th><th>LastName</th><th>BirthDate</th><th>MaritalStatus</th><th>Gender</th><th>EmailAddress</th><th>YearlyIncome</th><th>TotalChildren</th><th>NumberChildrenAtHome</th><th>Education</th><th>Occupation</th><th>HouseOwnerFlag</th><th>NumberCarsOwned</th><th>AddressLine1</th><th>AddressLine2</th><th>Phone</th><th>DateFirstPurchase</th><th>CommuteDistance</th></tr></thead><tbody><tr><td>11000</td><td>Australia</td><td>Jon</td><td>V</td><td>Yang</td><td>1971-10-06T00:00:00.000+0000</td><td>M</td><td>M</td><td>jon24@adventure-works.com</td><td>90000.0</td><td>2</td><td>0</td><td>Bachelors</td><td>Professional</td><td>1</td><td>0</td><td>3761 N. 14th St</td><td>NULL</td><td>1 (11) 500 555-0162</td><td>2011-01-19T00:00:00.000+0000</td><td>1-2 Miles</td></tr><tr><td>11001</td><td>Australia</td><td>Eugene</td><td>L</td
#         12940| United States|    Steven|      NULL|   Rogers|1970-09-21 00:00:00|            M|     M|steven29@adventur...|     80000.0|            3|                   3|          Bachelors|Skilled Manual|             1|              2| 7202 Sun View Court|        NULL|       120-555-0163|2013-06-12 00:00:00|      2-5 Miles|         null|         null|null| null|
#         13285|        Canada|      Kara|         P|   Chavez|1968-12-07 00:00:00|            M|     F|kara13@adventure-...|     80000.0|            4|                   3|    Partial College|  Professional|             1|              2|   3400 Folson Drive|        NULL|       676-555-0114|2013-02-06 00:00:00|      0-1 Miles|         null|         null|null| null|
#         13289|        Canada|Alexandria|         C|  Coleman|1978-08-22 00:00:00|            M|     F|alexandria6@adven...|     70000.0|            5|                   4|    Partial College|  Professional|             1|              3|  6652 Birch Park Rd|        NULL|       245-555-0181|2013-07-09 00:00:00|     5-10 Miles|         null|         null|null| null|
#         13623|     Australia|  Mitchell|      NULL|   Carson|1978-09-12 00:00:00|            M|     M|mitchell13@advent...|     80000.0|            0|                   0|          Bachelors|  Professional|             1|              3|  9715 San Francisco|        NULL|1 (11) 500 555-0163|2013-06-27 00:00:00|      10+ Miles|         null|         null|null| null|
#         13832|        France| Priscilla|         R|     Raji|1981-10-25 00:00:00|            S|     F|priscilla20@adven...|     20000.0|            0|                   0|        High School|        Manual|             0|              1|51, rue Henri Gagnon|        NULL|1 (11) 500 555-0125|2013-03-20 00:00:00|     5-10 Miles|         null|         null|null| null|
#         13840|        France|     Tommy|      NULL|      Pal|1979-10-01 00:00:00|            M|     M|tommy9@adventure-...|     10000.0|            0|                   0|Partial High School|        Manual|             1|              2|70, allée des Pri...|        NULL|1 (11) 500 555-0145|2012-02-25 00:00:00|      0-1 Miles|        13840|       Europe|  39|    2|
#         14450| United States|     Kevin|         R|   Butler|1975-04-06 00:00:00|            M|     M|kevin17@adventure...|    130000.0|            2|                   2|    Graduate Degree|    Management|             1|              2|602 Columbia Rive...|        NULL|       292-555-0173|2013-05-23 00:00:00|      0-1 Miles|         null|         null|null| null|
#         14570| United States|    Hannah|      NULL|Henderson|1976-10-19 00:00:00|            M|     F|hannah28@adventur...|     60000.0|            1|                   0|    Graduate Degree|  Professional|             1|              0|      6064 Tosca Way|        NULL|       671-555-0148|2013-05-05 00:00:00|      0-1 Miles|         null|         null|null| null|
#         14832|United Kingdom|     Barry|      NULL|     Rana|1980-04-30 00:00:00|            M|     M|barry12@adventure...|     40000.0|            1|                   0|          Bachelors|Skilled Manual|             1|              0|        8434 Kenmore|        NULL|1 (11) 500 555-0127|2011-06-14 00:00:00|      0-1 Miles|

# %%
display(all_data.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LoyaltyCardID</th><th>Region</th><th>FirstName</th><th>MiddleName</th><th>LastName</th><th>BirthDate</th><th>MaritalStatus</th><th>Gender</th><th>EmailAddress</th><th>YearlyIncome</th><th>TotalChildren</th><th>NumberChildrenAtHome</th><th>Education</th><th>Occupation</th><th>HouseOwnerFlag</th><th>NumberCarsOwned</th><th>AddressLine1</th><th>AddressLine2</th><th>Phone</th><th>DateFirstPurch
newE = newE.withColumn('Education', regexp_replace('Education', 'Bachelors', '4'))
newE = newE.withColumn('Education', regexp_replace('Education', 'Graduate Degree', '5'))
newCD = newE.withColumn('CommuteDistance', regexp_replace('CommuteDistance', ' Miles', ''))
newCD = newCD.withColumn('CommuteDistance', regexp_replace('CommuteDistance', '0-1', '1'))
newCD = newCD.withColumn('CommuteDistance', regexp_replace('CommuteDistance', '1-2', '2'))
newCD = newCD.withColumn('CommuteDistance', regexp_replace('CommuteDistance', '2-5', '5'))
newCD = newCD.withColumn('CommuteDistance', regexp_replace('CommuteDistance', '5-10', '10'))
#newCD = newCD.withColumn('CommuteDistance', regexp_replace('CommuteDistance', '10+', '11'))
display(newCD.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MaritalStatus</th><th>Gender</th><th>YearlyIncome</th><th>TotalChildren</th><th>NumberChildrenAtHome</th><th>Education</th><th>HouseOwnerFlag</th><th>NumberCarsOwned</th><th>CommuteDistance</th><th>Region</th><th>BirthDate</th><th>Age</th><th>Bikes</th></tr></thead><tbody><tr><td>2</td><td>1</td><td>20000.0</td><td>4</td><td>0</td><td>1</td><td>1</td><td>2</td><td>10</td><td>Australia</td><td>1958-09-19T00:00:00.000+0000</td><td>60</td><td>3</td></tr><tr><td>2</td><td>2</td><td>40000.0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>2</td><td>1</td><td>United States</td><td>1982-12-19T00:00:00.000+0000</td><td>0</td><td>0</td></tr><tr><td>1</td><td>2</td><td>40000.0</td><td>3</td><td>0</td><td>2</td><td>0</td><td>2</td><td>10</td><td>United States</td><td>1963-09-14T00:00:00.000+0000</td><td>55</td><td>2</td></tr><tr><td>2</td><td>2</td><td>100000.0</td><td>0</td><td>5</td><td>1</td><td>1</td><td>2</td><td>10+</td><td>Australia</td><td>1978-10-03T00:00:00.000+0000</td><td>0</td><td>0</td></tr><tr><td>2</td><td>1</td><td>70000.0</td><td>5</td><td>4</td><td>5</td><td>1</td><td>1</td><td>1</td><td>Canada</td><td>1964-01-15T00:00:00.000+0000</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
newCD.groupBy("CommuteDistance").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+-----+
# CommuteDistance|count|
# +---------------+-----+
#               5| 3234|
#             10+| 2494|
#               1| 6310|
#              10| 3214|
#               2| 3232|
# +---------------+-----+
#
# </div>

# %%
newCD
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">115</span><span class="ansired">]: </span>DataFrame[MaritalStatus: string, Gender: string, YearlyIncome: double, TotalChildren: int, NumberChildrenAtHome: int, Education: string, HouseOwnerFlag: int, NumberCarsOwned: int, CommuteDistance: string, Region: string, BirthDate: timestamp, Age: int, Bikes: int]
# </div>

# %%
trans3 = trans2.withColumn('CommuteDistance2',data_purchases_all.LoyaltyCardID).withColumn('Region2',data_purchases_all.Region)

# %%
 trans2.select(trans2.replace(" Miles", "").alias("name")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3348803873091858&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>trans2<span class="ansiyellow">.</span>select<span class="ansiyellow">(</span>trans2<span class="ansiyellow">.</span>replace<span class="ansiyellow">(</span><span class="ansiblue">&quot; Miles&quot;</span><span class="ansiyellow">,</span> <span class="ansiblue">&quot;&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>alias<span class="ansiyellow">(</span><span class="ansiblue">&quot;name&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>show<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansicyan">select</span><span class="ansiblue">(self, *cols)</span>
# <span class="ansigreen">   1263</span>         <span class="ansiyellow">[</span>Row<span class="ansiyellow">(</span>name<span class="ansiyellow">=</span><span class="ansiblue">u&apos;Alice&apos;</span><span class="ansiyellow">,</span> age<span class="ansiyellow">=</span><span class="ansicyan">12</span><span class="ansiyellow">)</span><span class="ansiyellow">,</span> Row<span class="ansiyellow">(</span>name<span class="ansiyellow">=</span><span class="ansiblue">u&apos;Bob&apos;</span><span class="ansiyellow">,</span> age<span class="ansiyellow">=</span><span class="ansicyan">15</span><span class="ansiyellow">)</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1264</span>         &quot;&quot;&quot;
# <span class="ansigreen">-&gt; 1265</span><span class="ansiyellow">         </span>jdf <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_jdf<span class="ansiyellow">.</span>select<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jcols<span class="ansiyellow">(</span><span class="ansiyellow">*</span>cols<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1266</span>         <span class="ansigreen">return</span> DataFrame<span class="ansiyellow">(</span>jdf<span class="ansiyellow">,</span> self<span class="ansiyellow">.</span>sql_ctx<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1267</span> <span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansicyan">_jcols</span><span class="ansiblue">(self, *cols)</span>
# <span class="ansigreen">   1059</span>         <span class="ansigreen">if</span> len<span class="ansiyellow">(</span>cols<span class="ansiyellow">)</span> <span class="ansiyellow">==</span> <span class="ansicyan">1</span> <span class="ansigreen">and</span> isinstance<span class="ansiyellow">(</span>cols<span class="ansiyellow">[</span><span class="ansicyan">0</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> list<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1060</span>             cols <span class="ansiyellow">=</span> cols<span class="ansiyellow">[</span><span class="ansicyan">0</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1061</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> self<span class="ansiyellow">.</span>_jseq<span class="ansiyellow">(</span>cols<span class="ansiyellow">,</span> _to_java_column<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1062</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1063</span>     <span class="ansigreen">def</span> _sort_cols<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> cols<span class="ansiyellow">,</span> kwargs<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansicyan">_jseq</span><span class="ansiblue">(self, cols, converter)</span>
# <span class="ansigreen">   1046</span>     <span class="ansigreen">def</span> _jseq<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> cols<span class="ansiyellow">,</span> converter<span class="ansiyellow">=</span><span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1047</span>         <span class="ansiblue">&quot;&quot;&quot;Return a JVM Seq of Columns from a list of Column or names&quot;&quot;&quot;</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1048</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _to_seq<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>sql_ctx<span class="ansiyellow">.</span>_sc<span class="ansiyellow">,</span> cols<span class="ansiyellow">,</span> converter<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1049</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1050</span>     <span class="ansigreen">def</span> _jmap<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> jm<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/column.py</span> in <span class="ansicyan">_to_seq</span><span class="ansiblue">(sc, cols, converter)</span>
# <span class="ansigreen">     64</span>     &quot;&quot;&quot;
# <span class="ansigreen">     65</span>     <span class="ansigreen">if</span> converter<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 66</span><span class="ansiyellow">         </span>cols <span class="ansiyellow">=</span> <span class="ansiyellow">[</span>converter<span class="ansiyellow">(</span>c<span class="ansiyellow">)</span> <span class="ansigreen">for</span> c <span class="ansigreen">in</span> cols<span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">     67</span>     <span class="ansigreen">return</span> sc<span class="ansiyellow">.</span>_jvm<span class="ansiyellow">.</span>PythonUtils<span class="ansiyellow">.</span>toSeq<span class="ansiyellow">(</span>cols<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     68</span> <span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/column.py</span> in <span class="ansicyan">&lt;listcomp&gt;</span><span class="ansiblue">(.0)</span>
# <span class="ansigreen">     64</span>     &quot;&quot;&quot;
# <span class="ansigreen">     65</span>     <span class="ansigreen">if</span> converter<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 66</span><span class="ansiyellow">         </span>cols <span class="ansiyellow">=</span> <span class="ansiyellow">[</span>converter<span class="ansiyellow">(</span>c<span class="ansiyellow">)</span> <span class="ansigreen">for</span> c <span class="ansigreen">in</span> cols<span c

# %%
import functions
col = trans2.select(functions.when(trans2.Bikes > 0, 1).otherwise(0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ImportError</span>                               Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3348803873091849&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span><span class="ansigreen">import</span> functions<span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> col <span class="ansiyellow">=</span> trans2<span class="ansiyellow">.</span>select<span class="ansiyellow">(</span>functions<span class="ansiyellow">.</span>when<span class="ansiyellow">(</span>trans2<span class="ansiyellow">.</span>Bikes <span class="ansiyellow">&gt;</span> <span class="ansicyan">0</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>otherwise<span class="ansiyellow">(</span><span class="ansicyan">0</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">ImportError</span>: No module named &apos;functions&apos;</div>
