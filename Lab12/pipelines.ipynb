# %% [markdown]
# You should already have a train.py, driver_training.py, and a parameters.json in an experiment folder. These resources will be used as the first step in the Machine Learning pipeline created and run later in this notebook.

# %%
# Set the folder for the experiment files used in Challenge 2
training_folder = 'driver-training'

# %% [markdown]
# ## register_model.py
# This script loads the model from where it was saved, and then registers it in the workspace. This will be the second step in the pipeline. The script is written to the experiment folder from this notebook for convenience.
#
# Note:  if we decide not to use AMLS pipelines and just want to use a more DevOps-centric approach (using gh actions or azdo pipelines instead of AMLS pipelines), we can.

# %%
# %%writefile $training_folder/register_model.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="driver_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_name = 'driver_model'
model_file = model_folder + "/" + model_name + ".pkl"

# Get metrics for registration
## TODO
## HINT: Try storing the metrics in the parent run, which will be
##       accessible during both the training and registration
##       child runs using the 'run.parent' API.
## See https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py#parent

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'driver_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing driver-training/register_model.py

# %% [markdown]
# ## Create an Azure Machine Learning Pipeline to Run the Scripts as a Pipeline
#
# See [this tutorial](https://github.com/MicrosoftDocs/mslearn-aml-labs/blob/master/05-Creating_a_Pipeline.ipynb) for a starting point
#
# Use the scikit-learn and lightgbm conda packages

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace
ws = Workspace.from_config()

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "automl"  #changeme

# Verify that the compute cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           vm_priority='lowpriority', 
                                                           max_nodes=4)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

env_name = training_folder + '-env'

# Create a Python environment for the experiment
env = Environment(env_name)
env.python.user_managed_dependencies = False  # Let Azure ML manage dependencies
env.docker.enabled = True                     # Use a docker container

# Create the pip and conda package dependencies
dependencies = CondaDependencies.create(
    conda_packages=['scikit-learn', 'pandas'],
    pip_packages=['azureml-sdk','lightgbm'])

# Add the package dependencies to the Python environment for the experiment
env.python.conda_dependencies = dependencies

# Register the environment 
env.register(workspace=ws)
registered_env = Environment.get(ws, env_name)

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Assign the target of the runconfig object to the cluster created above  
pipeline_run_config.target = pipeline_cluster

# Assign the environment of the runconfig object to the registered environment
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData(
    "model_folder", 
    datastore=ws.get_default_datastore())

# Create Estimator to train the model like we did before
estimator = Estimator(
    source_directory=training_folder,
    compute_target = pipeline_cluster,
    environment_definition=pipeline_run_config.environment,
    entry_script='driver_training.py')

# Create Step 1, which runs the estimator to train the model
train_step = EstimatorStep(
    name = "Train Model",
    estimator=estimator, 
    estimator_entry_script_arguments=['--output_folder', model_folder],
    outputs=[model_folder],
    compute_target = pipeline_cluster,
    allow_reuse = True)

# Create Step 2, which runs the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = training_folder,
                                script_name = "register_model.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline, which contains Step 1 & 2
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'driver-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()

# try monitoring this from the Azure portal as well.  
# make sure you understand approximately what this is doing
# Out:
# Pipeline is built.
# Created step Train Model [a666b9b5][a2df1157-3c62-4577-a86b-52b370f7eb40], (This step will run and generate new outputs)Created step Register Model [cf54a2ab][d0283340-d345-424d-8e67-734473351ef3], (This step will run and generate new outputs)
#
# Submitted PipelineRun ca1ed039-9500-471e-b2d0-1cfdfe6f8d11
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/ca1ed039-9500-471e-b2d0-1cfdfe6f8d11?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: ca1ed039-9500-471e-b2d0-1cfdfe6f8d11
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/ca1ed039-9500-471e-b2d0-1cfdfe6f8d11?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 9f717b83-a219-41fc-b09a-0a1474af9fbd
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/9f717b83-a219-41fc-b09a-0a1474af9fbd?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops
# StepRun( Train Model ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/08 20:34:05 Downloading source code...
# 2021/03/08 20:34:07 Finished downloading source code
# 2021/03/08 20:34:08 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/08 20:34:08 Successfully set up Docker network: acb_default_network
# 2021/03/08 20:34:08 Setting up Docker configuration...
# 2021/03/08 20:34:09 Successfully set up Docker configuration
# 2021/03/08 20:34:09 Logging in to registry: mlopse1388ade.azurecr.io
# 2021/03/08 20:34:10 Successfully logged into mlopse1388ade.azurecr.io
# 2021/03/08 20:34:10 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/08 20:34:10 Scanning for dependencies...
# 2021/03/08 20:34:11 Successfully scanned dependencies
# 2021/03/08 20:34:11 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# d7b631d130cb: Waiting
# 1536f6ca931b: Waiting
# 75ffe8dfb222: Waiting
# 86b4bf2f8d5f: Waiting
# 5335952fa8d3: Waiting
# 96fa3cc6fe10: Waiting
# e428dd9daa94: Waiting
# 73eef93b7466: Waiting
# d5a54c1fb97f: Waiting
# a613a9b4553c: Verifying Checksum
# a613a9b4553c: Download complete
# 73eef93b7466: Download complete
# acc000f01536: Verifying Checksum
# acc000f01536: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 8e097b52bfb8: Verifying Checksum
# 8e097b52bfb8: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# 8e097b52bfb8: Pull complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# StepRun( Train Model ) Status: Running
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/18 : USER root
#  ---> Running in 8564ac609823
# Removing intermediate container 8564ac609823
#  ---> 14e3505b2c42
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 5ef8b92f078b
# Removing intermediate container 5ef8b92f078b
#  ---> 009909b30c25
# Step 4/18 : WORKDIR /
#  ---> Running in c2038f1f89ff
# Removing intermediate container c2038f1f89ff
#  ---> 25a784944315
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> dc85c80ef61c
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 823e3d54dd22
# Removing intermediate container 823e3d54dd22
#  ---> f922ab2ec14f
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 2fcae522af01
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 2cc59264e828
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | 7          |   8%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #1         |  11%
# python-3.6.2         | 27.0 MB   | ##6        |  26%
# python-3.6.2         | 27.0 MB   | #####7     |  57%
# python-3.6.2         | 27.0 MB   | ########3  |  83%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######2   |  73%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | 3          |   4%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | #          |  10%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ######4    |  64%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######4    |  65%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | #          |  10%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #7         |  18%
# mkl-2019.4           | 204.1 MB  | ##         |  20%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##5        |  25%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###6       |  36%
# mkl-2019.4           | 204.1 MB  | ####       |  40%
# mkl-2019.4           | 204.1 MB  | ####2      |  43%
# mkl-2019.4           | 204.1 MB  | ####6      |  46%
# mkl-2019.4           | 204.1 MB  | ####9      |  49%
# mkl-2019.4           | 204.1 MB  | #####2     |  53%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | #####9     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######6    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  74%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ######7    |  68%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ####3      |  44%
# scikit-learn-0.23.2  | 6.9 MB    | ########   |  80%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ####       |  40%
# pandas-1.1.3         | 10.5 MB   | #########1 |  91%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###2       |  32%
# scipy-1.5.2          | 18.5 MB   | #######4   |  74%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.lmm980ab.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk~=1.18.0
#   Downloading azureml_sdk-1.18.0-py3-none-any.whl (4.4 kB)
# Collecting lightgbm
#   Downloading lightgbm-3.1.1-py2.py3-none-manylinux1_x86_64.whl (1.8 MB)
# Collecting azureml-train-automl-client~=1.18.0
#   Downloading azureml_train_automl_client-1.18.0-py3-none-any.whl (107 kB)
# Collecting azureml-pipeline~=1.18.0
#   Downloading azureml_pipeline-1.18.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-core~=1.18.0
#   Downloading azureml_core-1.18.0.post4-py3-none-any.whl (2.1 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.18.0
#   Downloading azureml_dataset_runtime-1.18.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-train~=1.18.0
#   Downloading azureml_train-1.18.0-py3-none-any.whl (3.3 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.22.0 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (0.23.2)
# Requirement already satisfied, skipping upgrade: scipy in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied, skipping upgrade: numpy in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: wheel in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (0.35.1)
# Collecting azureml-telemetry~=1.18.0
#   Downloading azureml_telemetry-1.18.0.post1-py3-none-any.whl (30 kB)
# Collecting azureml-automl-core~=1.18.0
#   Downloading azureml_automl_core-1.18.0.post2-py3-none-any.whl (186 kB)
# Collecting azureml-pipeline-steps~=1.18.0
#   Downloading azureml_pipeline_steps-1.18.0-py3-none-any.whl (62 kB)
# Collecting azureml-pipeline-core~=1.18.0
#   Downloading azureml_pipeline_core-1.18.0-py3-none-any.whl (306 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk~=1.18.0->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 1)) (2020.1)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.6-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-sdk~=1.18.0->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 1)) (2.8.1)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting azureml-dataprep<2.5.0a,>=2.4.0a
#   Downloading azureml_dataprep-2.4.5-py3-none-any.whl (28.2 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-train-core~=1.18.0
#   Downloading azureml_train_core-1.18.0.post1-py3-none-any.whl (8.6 MB)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from scikit-learn!=0.22.0->lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from scikit-learn!=0.22.0->lightgbm->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 2)) (0.17.0)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.18.0->azureml-sdk~=1.18.0->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib/python3.6/site-packages (from pyopenssl<20.0.0->azureml-core~=1.18.0->azureml-sdk~=1.18.0->-r /azureml-environment-setup/condaenv.lmm980ab.requirements.txt (line 1)) (1.15.0)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.7.2-py3-none-any.whl (11 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.3-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-train-restclients-hyperdrive~=1.18.0
#   Downloading azureml_train_restclients_hyperdrive-1.18.0-py3-none-any.whl (19 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.9.0-py2.py3-none-any.whl (59 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=c7e03eb3716e50e25f8eb006b2cb7333d1653492fb17c689b72bfbf82f21ac92
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: chardet, idna, urllib3, requests, isodate, oauthlib, requests-oauthlib, msrest, azure-common, pycparser, cffi, cryptography, PyJWT, adal, msrestazure, azure-mgmt-authorization, backports.weakref, backports.tempfile, azure-mgmt-storage, azure-mgmt-keyvault, pyopenssl, jeepney, SecretStorage, azure-graphrbac, contextlib2, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-mgmt-resource, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, websocket-client, docker, pathspec, jmespath, azure-mgmt-containerregistry, azureml-core, applicationinsights, azureml-telemetry, pyarrow, azureml-dataprep-rslex, azure-core, msal, portalocker, msal-extensions, azure-identity, cloudpickle, azureml-dataprep-native, distro, dotnetcore2, azureml-dataprep, fusepy, azureml-dataset-runtime, azureml-automl-core, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk, lightgbm
# Successfully installed PyJWT-1.7.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.18.0.post2 azureml-core-1.18.0.post4 azureml-dataprep-2.4.5 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.3 azureml-dataset-runtime-1.18.0 azureml-pipeline-1.18.0 azureml-pipeline-core-1.18.0 azureml-pipeline-steps-1.18.0 azureml-sdk-1.18.0 azureml-telemetry-1.18.0.post1 azureml-train-1.18.0 azureml-train-automl-client-1.18.0 azureml-train-core-1.18.0.post1 azureml-train-restclients-hyperdrive-1.18.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.6 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 fusepy-3.0.1 idna-2.10 importlib-metadata-3.7.2 isodate-0.6.0 jeepney-0.6.0 jmespath-0.10.0 jsonpickle-2.0.0 lightgbm-3.1.1 msal-1.9.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.13 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.58.0 zipp-3.4.1
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 2cc59264e828
#  ---> 70ff1e116fca
# Step 9/18 : ENV PATH /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/bin:$PATH
#  ---> Running in f6f7324ea1ed
# Removing intermediate container f6f7324ea1ed
#  ---> 2511be38d231
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 812b91d979c8
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 2a22b5c9a18d
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f
#  ---> Running in 6cd74f2ad01a
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 6cd74f2ad01a
#  ---> 4efcb32a9ded
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f
#  ---> Running in c9c61af1828a
# Removing intermediate container c9c61af1828a
#  ---> 2f1a685e3fe5
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/lib:$LD_LIBRARY_PATH
#  ---> Running in 81117de60152
# Removing intermediate container 81117de60152
#  ---> fa67d7bf97e7
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 04e4604a7073
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in c00a018b1714
# Removing intermediate container c00a018b1714
#  ---> 71914ce655c8
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 3c4c7554e3e2
# Removing intermediate container 3c4c7554e3e2
#  ---> 8a376f223da9
# Step 18/18 : CMD ["bash"]
#  ---> Running in 00670d4d74f5
# Removing intermediate container 00670d4d74f5
#  ---> bc603ed94209
# Successfully built bc603ed94209
# Successfully tagged mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41:latest
# 2021/03/08 20:38:21 Successfully executed container: acb_step_0
# 2021/03/08 20:38:21 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/08 20:38:21 Pushing image: mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41:latest, attempt 1
# The push refers to repository [mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41]
# 589f92a5c77c: Preparing
# 7135b6823dda: Preparing
# 17ec864c9b84: Preparing
# f0c2e4a7efab: Preparing
# 17cdb4a6d4db: Preparing
# 932e19e7a520: Preparing
# e793568e62be: Preparing
# 5c5d0f061727: Preparing
# ffa863077f9b: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 932e19e7a520: Waiting
# e793568e62be: Waiting
# 5c5d0f061727: Waiting
# ffa863077f9b: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# 87c128261339: Waiting
# dcc0cc99372e: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 589f92a5c77c: Pushed
# f0c2e4a7efab: Pushed
# 17ec864c9b84: Pushed
# 7135b6823dda: Pushed
# e793568e62be: Pushed
# 5c5d0f061727: Pushed
# 932e19e7a520: Pushed
# ffa863077f9b: Pushed
# 13e378616f24: Pushed
# efc99d952c3d: Pushed
# 9e292a80b88a: Pushed
# 2817caf0a082: Pushed
# aece08fd27fc: Pushed
# dcc0cc99372e: Pushed
# 87c128261339: Pushed
# 41a253a417e6: Pushed
# 5e1805eb9eb5: Pushed
# 8dab94e6d05c: Pushed
# 4caea5ef1f0b: Pushed
# e06660e80cf4: Pushed
#
# 17cdb4a6d4db: Pushed
# latest: digest: sha256:2372a0cf58b69da203b5358dadcee60cbb614eabe9a16cb14d519b7e8c7d7815 size: 4721
# 2021/03/08 20:40:35 Successfully pushed image: mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41:latest
# 2021/03/08 20:40:35 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 251.196397)
# 2021/03/08 20:40:35 Populating digests for step ID: acb_step_0...
# 2021/03/08 20:40:37 Successfully populated digests for step ID: acb_step_0
# 2021/03/08 20:40:37 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 133.871863)
# 2021/03/08 20:40:37 The following dependencies were found:
# 2021/03/08 20:40:37
# - image:
#     registry: mlopse1388ade.azurecr.io
#     repository: azureml/azureml_48f9507b78dff3e2d04909ad90792e41
#     tag: latest
#     digest: sha256:2372a0cf58b69da203b5358dadcee60cbb614eabe9a16cb14d519b7e8c7d7815
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
# Run ID: cay was successful after 6m33s
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe10c413fd0>: Failed to establish a new connection: [Errno 111] Connection refused',)': /history/v1.0/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourceGroups/MLOpsWorkshop/providers/Microsoft.MachineLearningServices/workspaces/mlops/experiments/driver-training-pipeline/runs/9f717b83-a219-41fc-b09a-0a1474af9fbd/details
# Streaming azureml-logs/55_azureml-execution-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt
# ========================================================================================================================
# 2021-03-08T20:46:05Z Starting output-watcher...
# 2021-03-08T20:46:05Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-08T20:46:07Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-03-08T20:46:08Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_48f9507b78dff3e2d04909ad90792e41
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# ef36d8c657ef: Pulling fs layer
# ff5c5fbdd572: Pulling fs layer
# ef33ce31dd49: Pulling fs layer
# 983539c01746: Pulling fs layer
# 579b0797750b: Pulling fs layer
# 00357c3c7f15: Pulling fs layer
# 57e96eac5fad: Pulling fs layer
# 2f3aa0ec7fd6: Pulling fs layer
# da78a9a128fa: Pulling fs layer
# 73eef93b7466: Waiting
# d5a54c1fb97f: Waiting
# 1536f6ca931b: Waiting
# d7b631d130cb: Waiting
# 75ffe8dfb222: Waiting
# 86b4bf2f8d5f: Waiting
# 5335952fa8d3: Waiting
# 96fa3cc6fe10: Waiting
# e428dd9daa94: Waiting
# 579b0797750b: Waiting
# 00357c3c7f15: Waiting
# 2f3aa0ec7fd6: Waiting
# 57e96eac5fad: Waiting
# da78a9a128fa: Waiting
# ff5c5fbdd572: Waiting
# ef33ce31dd49: Waiting
# ef36d8c657ef: Waiting
# 983539c01746: Waiting
# acc000f01536: Verifying Checksum
# acc000f01536: Download complete
# a613a9b4553c: Download complete
# 73eef93b7466: Download complete
# 8e097b52bfb8: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# 8e097b52bfb8: Pull complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# ef36d8c657ef: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# ff5c5fbdd572: Download complete
# ef33ce31dd49: Verifying Checksum
# ef33ce31dd49: Download complete
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 00357c3c7f15: Verifying Checksum
# 00357c3c7f15: Download complete
# 983539c01746: Verifying Checksum
# 983539c01746: Download complete
# 57e96eac5fad: Verifying Checksum
# 57e96eac5fad: Download complete
# da78a9a128fa: Verifying Checksum
# da78a9a128fa: Download complete
# 2f3aa0ec7fd6: Verifying Checksum
# 2f3aa0ec7fd6: Download complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Pull complete
# 579b0797750b: Verifying Checksum
# 579b0797750b: Download complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# ef36d8c657ef: Pull complete
# ff5c5fbdd572: Pull complete
# ef33ce31dd49: Pull complete
# 983539c01746: Pull complete
# 579b0797750b: Pull complete
# 00357c3c7f15: Pull complete
# 57e96eac5fad: Pull complete
# 2f3aa0ec7fd6: Pull complete
# da78a9a128fa: Pull complete
# Digest: sha256:2372a0cf58b69da203b5358dadcee60cbb614eabe9a16cb14d519b7e8c7d7815
# Status: Downloaded newer image for mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41:latest
# mlopse1388ade.azurecr.io/azureml/azureml_48f9507b78dff3e2d04909ad90792e41:latest
# 2021-03-08T20:46:35Z Check if container 9f717b83-a219-41fc-b09a-0a1474af9fbd already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt
# ===============================================================================================================
# [2021-03-08T20:47:04.276806] Entering job preparation.
# [2021-03-08T20:47:06.167130] Starting job preparation.
# [2021-03-08T20:47:06.167170] Extracting the control code.
# [2021-03-08T20:47:06.189156] fetching and extracting the control code on master node.
# [2021-03-08T20:47:06.189208] Starting extract_project.
# [2021-03-08T20:47:06.189260] Starting to extract zip file.
# [2021-03-08T20:47:06.854613] Finished extracting zip file.
# [2021-03-08T20:47:06.984652] Using urllib.request Python 3.0 or later
# [2021-03-08T20:47:06.984716] Start fetching snapshots.
# [2021-03-08T20:47:06.984764] Start fetching snapshot.
# [2021-03-08T20:47:06.984783] Retrieving project from snapshot: 7a50c125-b0d8-4a1c-98d2-28ca68fa5b63
# Starting the daemon thread to refresh tokens in background for process with pid = 64
# [2021-03-08T20:47:10.575083] Finished fetching snapshot.
# [2021-03-08T20:47:10.575197] Finished fetching snapshots.
# [2021-03-08T20:47:10.575205] Finished extract_project.
# [2021-03-08T20:47:10.585464] Finished fetching and extracting the control code.
# [2021-03-08T20:47:10.589877] downloadDataStore - Download from datastores if requested.
# [2021-03-08T20:47:10.591135] Start run_history_prep.
# [2021-03-08T20:47:10.639784] Entering context manager injector.
# Acquired lockfile /tmp/9f717b83-a219-41fc-b09a-0a1474af9fbd-datastore.lock to downloading input data references
# [2021-03-08T20:47:12.496553] downloadDataStore completed
# [2021-03-08T20:47:12.507275] Job preparation is complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/08 20:47:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/03/08 20:47:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-03-08T20:47:14.688824] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUser
# [290]	valid_0's auc: 0.638709
# [291]	valid_0's auc: 0.638731
# [292]	valid_0's auc: 0.638761
# [293]	valid_0's auc: 0.638759
# [294]	valid_0's auc: 0.638765
# [295]	valid_0's auc: 0.638742
# [296]	valid_0's auc: 0.638733
# [297]	valid_0's auc: 0.63876
# [298]	valid_0's auc: 0.638762
# [299]	valid_0's auc: 0.638762
# Early stopping, best iteration is:
# [279]	valid_0's auc: 0.638864
# Starting the daemon thread to refresh tokens in background for process with pid = 131
#
#
# [2021-03-08T20:47:34.413491] The experiment completed successfully. Finalizing run...
# ...
# >>>   2021/03/08 20:48:36 Check if container a35ea757-bd30-48b9-a0ef-25fad0727c79 already exist exited with 0,
# >>>
# >>>   2021/03/08 20:48:36 Check if container a35ea757-bd30-48b9-a0ef-25fad0727c79 already exist exited with 0,
# >>>
# >>>   2021/03/08 20:48:37 Attempt 1 of http call to https://eastus.experiments.azureml.net/history/v1.0/private/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourceGroups/MLOpsWorkshop/providers/Microsoft.MachineLearningServices/workspaces/mlops/runs/a35ea757-bd30-48b9-a0ef-25fad0727c79/spans
# >>>   2021/03/08 20:48:38 Container ssh is not required for job type.
# >>>   2021/03/08 20:48:38 Starting docker container succeeded.
# >>>   2021/03/08 20:48:38 Starting docker container succeeded.
# >>>   2021/03/08 20:48:38 Disk space after starting docker container: 379787MB
# >>>   2021/03/08 20:48:38 Begin execution of runSpecialJobTask
# >>>   2021/03/08 20:48:38 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/azureml_compute_logs
# >>>   2021/03/08 20:48:38 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"7a50c125-b0d8-4a1c-98d2-28ca68fa5b63","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/08 20:48:38 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/azureml_compute_logs/65_job_prep-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt
# >>>   2021/03/08 20:48:38 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/azureml_compute_logs/65_job_prep-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt
# >>>   2021/03/08 20:48:38 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/5ec7b93d-41b8-41f3-b135-933290234402/job-1/a35ea757-bd30-48b9-a_75bf4fdc-88b8-481e-b077-c891e5dbded7/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79;/azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"7a50c125-b0d8-4a1c-98d2-28ca68fa5b63","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/08 20:48:38 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/03/08 20:48:38 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-375bae375a81779e751d491adfe50902-8e0b62a768a1a156-01 -t a35ea757-bd30-48b9-a0ef-25fad0727c79 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/5ec7b93d-41b8-41f3-b135-933290234402/job-1/a35ea757-bd30-48b9-a_75bf4fdc-88b8-481e-b077-c891e5dbded7/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79;/azureml-envs/azureml_f78517e28d3a0e1ba34ed345dbf5dc5f/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79/mounts/workspaceblobstore/azureml/a35ea757-bd30-48b9-a0ef-25fad0727c79-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"7a50c125-b0d8-4a1c-98d2-28ca68fa5b63","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/08 20:48:42 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 1
# >>>   FilteredData: 0.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:39.150010] Entering job preparation.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.166270] Starting job preparation.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.166312] Extracting the control code.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.184294] fetching and extracting the control code on master node.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.184330] Starting extract_project.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.184375] Starting to extract zip file.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.865094] Finished extracting zip file.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.995376] Using urllib.request Python 3.0 or later
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.995439] Start fetching snapshots.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.995483] Start fetching snapshot.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:41.995504] Retrieving project from snapshot: 7a50c125-b0d8-4a1c-98d2-28ca68fa5b63
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 65
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.575914] Finished fetching snapshot.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.575977] Finished fetching snapshots.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.575985] Finished extract_project.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.586419] Finished fetching and extracting the control code.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.590601] downloadDataStore - Download from datastores if requested.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.591781] Start run_history_prep.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:45.638388] Entering context manager injector.
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: Acquired lockfile /tmp/a35ea757-bd30-48b9-a0ef-25fad0727c79-datastore.lock to downloading input data references
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:46.961951] downloadDataStore completed
# >>>   2021/03/08 20:48:47 runSpecialJobTask: preparation: [2021-03-08T20:48:46.973067] Job preparation is complete.
# >>>   2021/03/08 20:48:47 Execution of runSpecialJobTask completed
# >>>   2021/03/08 20:48:47 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/03/08 20:48:47 Process Exiting with Code:  0
# >>>   2021/03/08 20:48:47 All App Insights Logs was send successfully
# >>>
# 2021-03-08T20:48:47Z 127.0.0.1 slots=8 max-slots=8
# 2021-03-08T20:48:47Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt
# ===============================================================================================================
# [2021-03-08T20:48:59.442013] Entering job release
# [2021-03-08T20:49:01.185292] Starting job release
# [2021-03-08T20:49:01.209199] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 209
# [2021-03-08T20:49:01.210297] job release stage : upload_datastore starting...
# [2021-03-08T20:49:01.210608] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-08T20:49:01.213020] job release stage : copy_batchai_cached_logs starting...
# [2021-03-08T20:49:01.213167] job release stage : execute_job_release starting...
# [2021-03-08T20:49:01.219597] job release stage : copy_batchai_cached_logs completed...
# [2021-03-08T20:49:01.220685] Entering context manager injector.
# [2021-03-08T20:49:01.458751] job release stage : upload_datastore completed...
# [2021-03-08T20:49:01.472514] job release stage : send_run_telemetry starting...
# [2021-03-08T20:49:01.707121] get vm size and vm region successfully.
# [2021-03-08T20:49:01.730104] job release stage : execute_job_release completed...
# [2021-03-08T20:49:01.888653] get compute meta data successfully.
# [2021-03-08T20:49:02.112843] post artifact meta request successfully.
# [2021-03-08T20:49:02.142342] upload compute record artifact successfully.
# [2021-03-08T20:49:02.365876] job release stage : send_run_telemetry completed...
# [2021-03-08T20:49:02.366232] Job release is complete
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': 'a35ea757-bd30-48b9-a0ef-25fad0727c79', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-03-08T20:48:26.845697Z', 'endTimeUtc': '2021-03-08T20:49:14.243798Z', 'properties': {'ContentSnapshotId': '7a50c125-b0d8-4a1c-98d2-28ca68fa5b63', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'd0283340-d345-424d-8e67-734473351ef3', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cf54a2ab', 'azureml.pipelinerunid': 'ca1ed039-9500-471e-b2d0-1cfdfe6f8d11', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'automl', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/9f717b83-a219-41fc-b09a-0a1474af9fbd/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'driver-training-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.18.0', 'lightgbm']}, 'scikit-learn', 'pandas'], 'name': 'azureml_f78517e28d3a0e1ba34ed345dbf5dc5f'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.a35ea757-bd30-48b9-a0ef-25fad0727c79/azureml-logs/55_azureml-execution-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt?sv=2019-02-02&sr=b&sig=VUKBN3DWutmqrhgQwnybv6556FbqzFZQsy78PEsOL6k%3D&st=2021-03-08T20%3A39%3A02Z&se=2021-03-09T04%3A49%3A02Z&sp=r', 'azureml-logs/65_job_prep-tvmps_77be8035c2ec1a0665bed3a13bd58b317307236bda336dabbf94159e2b50fda8_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/Exper ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ca1ed039-9500-471e-b2d0-1cfdfe6f8d11', 'status': 'Completed', 'startTimeUtc': '2021-03-08T20:33:34.840348Z', 'endTimeUtc': '2021-03-08T20:49:18.498185Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.ca1ed039-9500-471e-b2d0-1cfdfe6f8d11/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=1V6FgSIr3YWHTr6ijTwoOAtLI0yDWc4%2FbyDscu4fWqM%3D&st=2021-03-08T20%3A23%3A54Z&se=2021-03-09T04%3A33%3A54Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.ca1ed039-9500-471e-b2d0-1cfdfe6f8d11/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=2kMkSardyWS9MHTUtIOXluawhAA6lSfYeoJVMJ0FhHI%3D&st=2021-03-08T20%3A23%3A54Z&se=2021-03-09T04%3A33%3A54Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.ca1ed039-9500-471e-b2d0-1cfdfe6f8d11/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=%2BUmtg9U18UAaa1531FFa25REhiS1rDMtmKX1ISaCbE0%3D&st=2021-03-08T20%3A23%3A54Z&se=2021-03-09T04%3A33%3A54Z&sp=r'}}
# 'Finished'

# %%
# Print the model name, version, tag, and properties
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# driver_model version: 1
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 1
#
#
# compliance-classifier version: 17
# 	 type : classification
# 	 run_id : 0767a613-e8c2-4811-ae6b-64369e340725
# 	 build_number : 20201217.1
#
#
# BikeBuyer.mml version: 4
#
#
# AutoMLb9be0a22f28 version: 1
#
#
# compliance-classifier version: 16
# 	 type : classification
# 	 run_id : a7eb32c9-3207-4a2c-865a-d65fba7946ba
# 	 build_number : 20201119.1
#
#
# compliance-classifier version: 15
# 	 type : classification
# 	 run_id : 8e84d5f5-54c9-48c9-b733-9bbbcd86558b
# 	 build_number : 20201118.1
#
#
# IBM_attrition_model version: 1
# 	 area : HR
# 	 type : attrition
#
#
# AutoML015fd913221 version: 1
#
#
# diabetes_model version: 1
# 	 Training context : Inline Training
# 	 AUC : 0.8857431111811085
# 	 Accuracy : 0.9002222222222223
#
#
# glove-text-classifier version: 1
# 	 type : classification
# 	 run_id : glove-embeddings-classifier_1597854176_900c5cea
#
#
# compliance-classifier version: 14
# 	 type : classification
# 	 run_id : 3886cc4f-8a9d-4608-abea-c588a9074912
# 	 build_number : 20200428.2
#
#
# compliance-classifier version: 13
# 	 type : classification
# 	 run_id : 36b88b87-4c5e-4d64-8fa3-ae721eda608d
# 	 build_number : 20200428.1
#
#
# compliance-classifier version: 12
# 	 type : classification
# 	 run_id : 46b16ce1-7719-4faa-84ae-6d6a4835da08
# 	 build_number : 20200427.1
#
#
# compliance-classifier-qvc version: 1
# 	 type : classification
# 	 run_id : deep-learning-qvc_1587989276_00ba8da2
#
#
# BikeBuyer.mml version: 3
#
#
# compliance-classifier version: 11
# 	 type : classification
# 	 run_id : 8c546c17-d0a9-43dc-92c6-c464fdfe68e2
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 10
# 	 type : classification
# 	 run_id : 3d1df6b1-fd5e-42e1-9021-44038a2aeabd
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 9
# 	 type : classification
# 	 run_id : 22e820b2-1015-4ac2-88d4-c80eed9e0006
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 8
# 	 type : classification
# 	 run_id : 1d751a7d-5470-473a-8e9b-5b22be5fb2bb
# 	 build_number : 20191028.1
#
#
# compliance-classifier version: 7
# 	 type : classification
# 	 run_id : db72b465-9ae9-4e22-8a3c-22b81e09478b
# 	 build_number : 20191025.1
#
#
# compliance-classifier version: 6
# 	 type : classification
# 	 run_id : 5c59dcd9-f23b-4abf-a1b5-af151927f0e7
# 	 build_number : 20191024.4
#
#
# compliance-classifier version: 5
# 	 type : classification
# 	 run_id : 5c7a146e-bb1a-40a8-a3a0-ac1f953205f4
# 	 build_number : 20191024.3
#
#
# compliance-classifier version: 4
# 	 type : classification
# 	 run_id : 1a7ba8f6-f615-4ec2-8c1f-6926c2517234
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 3
# 	 type : classification
# 	 run_id : 138fdae4-b92f-494d-8d63-ed884f655332
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 2
#
#
# compliance-classifier version: 1
# 	 type : classification
# 	 run_id : deep-learning_1571935012_a8c321f6
#
#
# BikeBuyer.mml version: 2
#
#
# BikeBuyer.mml version: 1
