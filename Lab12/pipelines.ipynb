# %% [markdown]
# In this lab we are going to build an Azure MLS pipeline that will automatically train and then register the model.
#
# You should already have a
#  * train.py
#  * driver_training.py
#  * parameters.json
#
# in an experiment folder. These resources will be used as the first step in the Machine Learning pipeline created and run later in this notebook.
#
# We also need to create a python file to register the model.
#
# Then we'll put it all together in one AMLS pipeline.
#
# If you don't want to use AMLS pipelines we can just call these python files directly from our DevOps tool of choice.

# %%
# !pwd
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/davew202105/code/git/MLOps-E2E-sdkv2/Lab12

# %%
# Set the folder for the experiment files used in previous lab
training_folder = 'driver-training'
experiment = 'driver-training'

# %% [markdown]
# ## register_model.py
# This script loads the model from where it was saved, and then registers it in the workspace. This will be the second step in the pipeline. The script is written to the experiment folder from this notebook for convenience.
#
# Note:  if we decide not to use AMLS pipelines and just want to use a more DevOps-centric approach (using gh actions or azdo pipelines instead of AMLS pipelines), we can.

# %%
# %%writefile $training_folder/register_model.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="driver_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_name = 'driver_model'
model_file = model_folder + "/" + model_name + ".pkl"

# Get metrics for registration
## TODO
## HINT: Try storing the metrics in the parent run, which will be
##       accessible during both the training and registration
##       child runs using the 'run.parent' API.
## See https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py#parent

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'driver_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Overwriting driver-training/register_model.py

# %% [markdown]
# ## Create an Azure Machine Learning Pipeline to Run the Scripts as a Pipeline
#
# See [this tutorial](https://github.com/MicrosoftDocs/mslearn-aml-labs/blob/master/05-Creating_a_Pipeline.ipynb) for a starting point
#
# Use the scikit-learn and lightgbm conda packages

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace
ws = Workspace.from_config()

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "automl"  #changeme

# Verify that the compute cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           vm_priority='lowpriority', 
                                                           max_nodes=4)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.core import Environment, Experiment, ScriptRunConfig
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration
from azureml.pipeline.core import Pipeline, PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.core.runconfig import RunConfiguration, DockerConfiguration
from azureml.widgets import RunDetails

# %%
# we need an environment which we already created and persisted in the last lab

# here's how we can see a list of our custom environments
envs = Environment.list(workspace=ws)

for env in envs:
    if not (env.startswith("AzureML")):
        print("Name",env)
        print("packages", envs[env].python.conda_dependencies.serialize_to_string())
        
# the env should be called driver_training

# %%
env_name = experiment

# connect to the existing python env we already registered
registered_env = Environment.get(
    workspace=ws,
    name=env_name)

# %%
# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Assign the target of the runconfig object to the cluster created above  
pipeline_run_config.target = pipeline_cluster

# Assign the environment of the runconfig object to the registered environment
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# Let's start build the pipeline in code.  For now we just need the training script and the model registration script.  We'll add more later.

# %%
# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData(
    "outputs", 
    datastore=ws.get_default_datastore())

# before we created a src (ScriptRunConfig).  This is slightly different:  we create a PythonScriptStep
args = ['--output_folder',"outputs"]
docker_config = DockerConfiguration(use_docker=True)

# now we want to use that src as Step1 of the pipeline
train_step = PythonScriptStep(
        name = "Train Model",
        source_directory = training_folder,
        script_name = "driver_training.py",
        arguments=args,
        outputs=[model_folder],
        compute_target=pipeline_cluster,  # we built this above
        allow_reuse = True,
        runconfig = pipeline_run_config
    )
register_step = PythonScriptStep(
        name = "Register Model",
        source_directory = training_folder,
        script_name = "register_model.py",
        arguments=['--model_folder', model_folder],
        inputs = [model_folder],
        compute_target=pipeline_cluster,  # we built this above
        allow_reuse = True,
        runconfig = pipeline_run_config
    )
print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
# Construct the pipeline, which contains Step 1 & 2
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")
# Out:
# Pipeline is built.

# %% [markdown]
# Some notes:
#
# * **If** you have a multi-stage pipeline with separate train and register model stages, and need so log metrics on the first stage and access them from the second, please see [Azure ML Python SDK - Run Class](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py) and in particular `run.parent.log()` and `run.parent.get_metrics()`. This (obviously) will only work when there *is* a parent run, i.e., doesn't work if runnning `train.py` or `register_model.py` by themselves.
# * When registering models, also keep in mind the differences between `run.register_model()` and `Model.register()` from [Azure ML Python SDK - Model class](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.model(class)?view=azure-ml-py). Only the first allows you keep full traceability between the context of the run/dataset and the trained model. To use it, remember you must first explicitly upload the model with `run.upload_file()`, and then use the name of the model as the `model_path` parameter.
# * If you deploy your model to Azure Container Instances and it just hangs with no apparent error message, check the logs for the container in Azure Container Instances (or start the container  locally using Docker and use its logs to debug the problem). **If you see this, there might possibly be an error in the `init()` function of your scoring script.**. You can try to run the container locally in your PC to diagnose this problem.

# %%
# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'driver-training-pipeline-v2')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
# Out:
# Created step Train Model [253c6409][a5bdd85e-f60b-471b-901d-f4cd03e09740], (This step will run and generate new outputs)
# Created step Register Model [69f042e0][c1631a56-c323-411b-9880-5bfb2317e400], (This step will run and generate new outputs)
# Submitted PipelineRun e104aaf3-0c5a-4d82-9d94-95eb7f6b468e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e104aaf3-0c5a-4d82-9d94-95eb7f6b468e?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# Pipeline submitted for execution.

# %%
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()

# try monitoring this from the Azure portal as well.  
# make sure you understand approximately what this is doing
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: e104aaf3-0c5a-4d82-9d94-95eb7f6b468e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e104aaf3-0c5a-4d82-9d94-95eb7f6b468e?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRun Status: Running
#
#
# StepRunId: ac02198e-ff79-44b4-8d60-65627366c535
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ac02198e-ff79-44b4-8d60-65627366c535?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# ========================================================================================================================
# 2021-05-19T20:45:41Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/ac02198e-ff79-44b4-8d60-65627366c535/mounts/workspaceblobstore
# 2021-05-19T20:45:42Z Starting output-watcher...
# 2021-05-19T20:45:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-19T20:45:42Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-19T20:45:42Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_777d58e1f33827e3873cd78466257dcc
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# 1a11206eb85a: Pulling fs layer
# 8c2198f65752: Pulling fs layer
# 6900d1689fd4: Pulling fs layer
# 899cd08afcb8: Pulling fs layer
# 8c1a1ecd2f41: Pulling fs layer
# 4c6ec688ebe3: Waiting
# e5d2a1bf49fe: Pulling fs layer
# 3688270a99d2: Pulling fs layer
# e544ee0f522d: Waiting
# 574f361512d6: Waiting
# 42fab3dfb64b: Pulling fs layer
# 5fba3bd4a2c4: Waiting
# d84fd6681dc7: Pulling fs layer
# db4d1e2d7079: Waiting
# c655136086be: Waiting
# 7e0ea9d0a1ab: Waiting
# 2ec37f44090c: Waiting
# 8c2198f65752: Waiting
# da005f826951: Waiting
# 1a11206eb85a: Waiting
# 6900d1689fd4: Waiting
# 899cd08afcb8: Waiting
# 3688270a99d2: Waiting
# 8c1a1ecd2f41: Waiting
# 42fab3dfb64b: Waiting
# d84fd6681dc7: Waiting
# e5d2a1bf49fe: Waiting
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 5dfa26c6b9c9: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# 4007a89234b4: Pull complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 7e0ea9d0a1ab: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 1a11206eb85a: Verifying Checksum
# 1a11206eb85a: Download complete
# 8c2198f65752: Download complete
# 6900d1689fd4: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 899cd08afcb8: Verifying Checksum
# 899cd08afcb8: Download complete
# e5d2a1bf49fe: Verifying Checksum
# e5d2a1bf49fe: Download complete
# 3688270a99d2: Verifying Checksum
# 3688270a99d2: Download complete
# d84fd6681dc7: Verifying Checksum
# d84fd6681dc7: Download complete
# 42fab3dfb64b: Verifying Checksum
# 42fab3dfb64b: Download complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 8c1a1ecd2f41: Verifying Checksum
# 8c1a1ecd2f41: Download complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# 1a11206eb85a: Pull complete
# 8c2198f65752: Pull complete
# 6900d1689fd4: Pull complete
# 899cd08afcb8: Pull complete
# 8c1a1ecd2f41: Pull complete
# e5d2a1bf49fe: Pull complete
# 3688270a99d2: Pull complete
# 42fab3dfb64b: Pull complete
# d84fd6681dc7: Pull complete
# Digest: sha256:563d0eae6a5f3a2213d3ba33fba98bacde15ae3288456b51f8299804f9ab3660
# Status: Downloaded newer image for mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc:latest
# mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc:latest
# 2021-05-19T20:46:06Z Check if container ac02198e-ff79-44b4-8d60-65627366c535 already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# ===============================================================================================================
# [2021-05-19T20:46:38.826703] Entering job preparation.
# [2021-05-19T20:46:40.158737] Starting job preparation.
# [2021-05-19T20:46:40.158785] Extracting the control code.
# [2021-05-19T20:46:40.178474] fetching and extracting the control code on master node.
# [2021-05-19T20:46:40.178529] Starting extract_project.
# [2021-05-19T20:46:40.178580] Starting to extract zip file.
# [2021-05-19T20:46:40.636731] Finished extracting zip file.
# [2021-05-19T20:46:40.774393] Using urllib.request Python 3.0 or later
# [2021-05-19T20:46:40.774457] Start fetching snapshots.
# [2021-05-19T20:46:40.774502] Start fetching snapshot.
# [2021-05-19T20:46:40.774521] Retrieving project from snapshot: a0bc62b2-c5d3-4175-928e-79ab648193b6
# Starting the daemon thread to refresh tokens in background for process with pid = 55
# [2021-05-19T20:46:43.563214] Finished fetching snapshot.
# [2021-05-19T20:46:43.563269] Finished fetching snapshots.
# [2021-05-19T20:46:43.563277] Finished extract_project.
# [2021-05-19T20:46:43.575107] Finished fetching and extracting the control code.
# [2021-05-19T20:46:43.579255] downloadDataStore - Download from datastores if requested.
# [2021-05-19T20:46:43.580630] Start run_history_prep.
# [2021-05-19T20:46:43.638442] Entering context manager injector.
# Acquired lockfile /tmp/ac02198e-ff79-44b4-8d60-65627366c535-datastore.lock to downloading input data references
# [2021-05-19T20:46:44.149093] downloadDataStore completed
# [2021-05-19T20:46:44.152359] Job preparation is complete.
#
# Streaming azureml-logs/75_job_post-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# ===============================================================================================================
# [2021-05-19T20:47:09.581138] Entering job release
# [2021-05-19T20:47:10.715266] Starting job release
# [2021-05-19T20:47:10.720245] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 179
# [2021-05-19T20:47:10.720668] job release stage : upload_datastore starting...
# [2021-05-19T20:47:10.723493] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-19T20:47:10.731297] job release stage : execute_job_release starting...
# [2021-05-19T20:47:10.731616] job release stage : copy_batchai_cached_logs starting...
# [2021-05-19T20:47:10.732471] job release stage : copy_batchai_cached_logs completed...
# [2021-05-19T20:47:10.732995] Entering context manager injector.
# [2021-05-19T20:47:10.751229] job release stage : upload_datastore completed...
# [2021-05-19T20:47:10.873800] job release stage : execute_job_release completed...
# [2021-05-19T20:47:10.890320] job release stage : send_run_telemetry starting...
# [2021-05-19T20:47:11.055609] get vm size and vm region successfully.
# [2021-05-19T20:47:11.270389] get compute meta data successfully.
# [2021-05-19T20:47:11.570380] post artifact meta request successfully.
# [2021-05-19T20:47:11.598460] upload compute record artifact successfully.
# [2021-05-19T20:47:11.598551] job release stage : send_run_telemetry completed...
# [2021-05-19T20:47:11.599022] Job release is complete
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'ac02198e-ff79-44b4-8d60-65627366c535', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-05-19T20:45:36.832016Z', 'endTimeUtc': '2021-05-19T20:47:37.019504Z', 'properties': {'ContentSnapshotId': 'a0bc62b2-c5d3-4175-928e-79ab648193b6', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a5bdd85e-f60b-471b-901d-f4cd03e09740', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '253c6409', 'azureml.pipelinerunid': 'e104aaf3-0c5a-4d82-9d94-95eb7f6b468e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'driver_training.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--output_folder', 'outputs'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'automl', 'dataReferences': {'outputs': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/ac02198e-ff79-44b4-8d60-65627366c535/outputs', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'driver-training', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}, 'pip', 'scikit-learn', 'lightgbm'], 'name': 'azureml_f56354669bb7d4c82aeb289ec6d61f97'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.ac02198e-ff79-44b4-8d60-65627366c535/azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt?sv=2019-02-02&sr=b&sig=cKA3VIPiJ4MeGWtnKT1BEalU1ONaoY6ydEfKz7TyjJ8%3D&st=2021-05-19T20%3A37%3A12Z&se=2021-05-20T04%3A47%3A12Z&sp=r', 'azureml-logs/65_job_prep-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cb ...
#
#
#
#
# StepRunId: d5f79556-1140-45ed-8714-e8dfc103b456
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/d5f79556-1140-45ed-8714-e8dfc103b456?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# ========================================================================================================================
# 2021-05-19T20:47:49Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore
# 2021-05-19T20:47:50Z Starting output-watcher...
# 2021-05-19T20:47:50Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-19T20:47:50Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-19T20:47:50Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_777d58e1f33827e3873cd78466257dcc
# Digest: sha256:563d0eae6a5f3a2213d3ba33fba98bacde15ae3288456b51f8299804f9ab3660
# Status: Image is up to date for mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc:latest
# mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc:latest
# 2021-05-19T20:47:51Z Check if container d5f79556-1140-45ed-8714-e8dfc103b456 already exist exited with 0,
#
# 25fcd2745b2b1d797d62832c8c5807cc268d718e88417abb4d3a8e42a39fc2f9
# 2021-05-19T20:47:51Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-05-19T20:47:51Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e8b7ebd35dc58a0b13557efa19b0ec61-4d871e1fc78ebfbf-01 -sshRequired=false]
# 2021/05/19 20:47:51 Starting App Insight Logger for task:  containerSetup
# 2021/05/19 20:47:51 Version: 3.0.01597.0004 Branch: 2021-05-17-bing-hotfix Commit: 974f3e4
# 2021/05/19 20:47:51 Entered ContainerSetupTask - Preparing infiniband
# 2021/05/19 20:47:51 Starting infiniband setup
# 2021/05/19 20:47:51 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/19 20:47:51 Returning Python Version as 3.6
# 2021/05/19 20:47:51 VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/19 20:47:51 VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-05-19T20:47:51Z VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/19 20:47:51 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/05/19 20:47:51 Not setting up Infiniband in Container
# 2021/05/19 20:47:51 Not setting up Infiniband in Container
# 2021-05-19T20:47:51Z Not setting up Infiniband in Container
# 2021/05/19 20:47:51 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/19 20:47:51 Returning Python Version as 3.6
# 2021/05/19 20:47:51 sshd inside container not required for job, skipping setup.
# 2021/05/19 20:47:52 All App Insights Logs was send successfully
# 2021/05/19 20:47:52 App Insight Client has already been closed
# 2021/05/19 20:47:52 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-05-19T20:47:52Z Starting docker container succeeded.
# 2021-05-19T20:47:59Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/05/19 20:47:48 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/05/19 20:47:48 Version: 3.0.01597.0004 Branch: 2021-05-17-bing-hotfix Commit: 974f3e4
# >>>   2021/05/19 20:47:48 runtime.GOOS linux
# >>>   2021/05/19 20:47:48 Checking if '/tmp' exists
# >>>   2021/05/19 20:47:48 Reading dyanamic configs
# >>>   2021/05/19 20:47:48 Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=gCpFfTbL8hPl%2BzV43hBdfOZC4SuKqZoJraIo10S4%2FYw%3D
# >>>   2021/05/19 20:47:48 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: not a directory
# >>>   2021/05/19 20:47:48 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: true. Is Azsecpack enabled: true,
# >>>   2021/05/19 20:47:48 Starting Azsecpack installation on machine: 45609bf9fbe84620ade0f2782a3e2d78000000#72f988bf-86f1-41af-91ab-2d7cd011db47#52061d21-01dd-4f9e-aca9-60fff4d67ee2#mlopsworkshop#mlops#automl
# >>>   2021/05/19 20:47:48 Is Azsecpack enabled: true, GetDisableVsatlsscan: true
# >>>   2021/05/19 20:47:48 Start preparing environment for azsecpack installation. MachineName is 45609bf9fbe84620ade0f2782a3e2d78000000
# >>>
# >>>   2021/05/19 20:47:48
# >>>   2021/05/19 20:47:48
# >>>   2021/05/19 20:47:48 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/05/19 20:47:48 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/05/19 20:47:48 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/19 20:47:48 GPU count found on the node: 0
# >>>   2021/05/19 20:47:48 AMLComputeXDSEndpoint:  https://eastus-prodk8ds.batchai.core.windows.net
# >>>   2021/05/19 20:47:48 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/05/19 20:47:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config
# >>>   2021/05/19 20:47:48 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/05/19 20:47:48 Starting identity responder.
# >>>   2021/05/19 20:47:48 Starting identity responder.
# >>>   2021/05/19 20:47:48 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/05/19 20:47:48 Logfile used for identity responder: /mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/IdentityResponderLog-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# >>>   2021/05/19 20:47:48 Logfile used for identity responder: /mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/IdentityResponderLog-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# >>>   2021/05/19 20:47:48 Started Identity Responder for job.
# >>>   2021/05/19 20:47:48 Started Identity Responder for job.
# >>>   2021/05/19 20:47:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd
# >>>   2021/05/19 20:47:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/shared
# >>>   2021/05/19 20:47:48 From the policy service, the filtering patterns is: , data store is
# >>>   2021/05/19 20:47:48 Mounting job level file systems
# >>>   2021/05/19 20:47:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts
# >>>   2021/05/19 20:47:48 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.amlcompute.datastorecredentials
# >>>   2021/05/19 20:47:48 Datastore credentials file not found, skipping.
# >>>   2021/05/19 20:47:48 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.master.runtimesastokens
# >>>   2021/05/19 20:47:48 Runtime sas tokens file not found, skipping.
# >>>   2021/05/19 20:47:48 No NFS configured
# >>>   2021/05/19 20:47:48 No Azure File Shares configured
# >>>   2021/05/19 20:47:48 Mounting blob file systems
# >>>   2021/05/19 20:47:48 Blobfuse runtime version 1.3.6
# >>>   2021/05/19 20:47:48 Mounting azureml-blobstore-ff8ef3fc-dbd9-4bd7-8d8a-d734bf3dfc40 container from mlops3730696013 account at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore
# >>>   2021/05/19 20:47:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/05/19 20:47:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/05/19 20:47:48 Blobfuse cache size set to 369926 MB.
# >>>   2021/05/19 20:47:48 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=369926 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/05/19 20:47:48 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore
# >>>   2021/05/19 20:47:50 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore
# >>>   2021/05/19 20:47:50 Successfully mounted azureml-blobstore-ff8ef3fc-dbd9-4bd7-8d8a-d734bf3dfc40 container from mlops3730696013 account at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore
# >>>   2021/05/19 20:47:50 Created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456
# >>>   2021/05/19 20:47:50 No unmanaged file systems configured
# >>>   2021/05/19 20:47:50 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/19 20:47:50 From the policy service, the filtering patterns is: , data store is
# >>>   2021/05/19 20:47:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs
# >>>   2021/05/19 20:47:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/logs
# >>>   2021/05/19 20:47:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/outputs
# >>>   2021/05/19 20:47:50 Starting output-watcher...
# >>>   2021/05/19 20:47:50 Single file input dataset is enabled.
# >>>   2021/05/19 20:47:50 Start to pulling docker image: mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc
# >>>   2021/05/19 20:47:50 Start pull docker image: mlopse1388ade.azurecr.io
# >>>   2021/05/19 20:47:50 Getting credentials for image mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc with url mlopse1388ade.azurecr.io
# >>>   2021/05/19 20:47:50 Container registry is ACR.
# >>>   2021/05/19 20:47:50 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/05/19 20:47:50 Getting ACR Credentials from EMS for environment driver-training:1
# >>>   2021/05/19 20:47:50 Requesting XDS for registry details.
# >>>   2021/05/19 20:47:50 Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourceGroups/mlopsworkshop/workspaces/mlops/clusters/automl/nodes/tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d?api-version=2018-02-01
# >>>   2021/05/19 20:47:50 Got container registry details from credentials service for registry address: mlopse1388ade.azurecr.io.
# >>>   2021/05/19 20:47:50 Writing ACR Details to file...
# >>>   2021/05/19 20:47:50 Copying ACR Details file to worker nodes...
# >>>   2021/05/19 20:47:50 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/05/19 20:47:50 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/05/19 20:47:50 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/05/19 20:47:50 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/05/19 20:47:50 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/05/19 20:47:50 EMS returned mlopse1388ade.azurecr.io for environment driver-training
# >>>   2021/05/19 20:47:50 Save docker credentials for image mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc in /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd/docker_login_8AE5E2FBDD5B6837
# >>>   2021/05/19 20:47:50 start login to the docker registry
# >>>   2021/05/19 20:47:50 Successfully logged into the docker registry.
# >>>   2021/05/19 20:47:50 Start run pull docker image command
# >>>   2021/05/19 20:47:50 Pull docker image succeeded.
# >>>   2021/05/19 20:47:50 Removed docker config dir /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd/docker_login_8AE5E2FBDD5B6837
# >>>   2021/05/19 20:47:50 Pull docker image time: 587.809012ms
# >>>
# >>>   2021/05/19 20:47:51 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/05/19 20:47:51 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/19 20:47:51 Setting the memory limit for docker container to be 56009 MB
# >>>   2021/05/19 20:47:51 The env variable file size is 39686 bytes
# >>>   2021/05/19 20:47:51 Creating parent cgroup 'd5f79556-1140-45ed-8714-e8dfc103b456' for Containers used in Job
# >>>   2021/05/19 20:47:51 Add parent cgroup 'd5f79556-1140-45ed-8714-e8dfc103b456' to container 'd5f79556-1140-45ed-8714-e8dfc103b456'
# >>>   2021/05/19 20:47:51 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/05/19 20:47:51 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,d5f79556-1140-45ed-8714-e8dfc103b456,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,56009m,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/d5f79556-1140-45ed-8714-e8dfc103b456/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/d5f79556-1140-45ed-8714-e8dfc103b456/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.batchai.envlist,--cgroup-parent=/d5f79556-1140-45ed-8714-e8dfc103b456/,--shm-size,2g
# >>>   2021/05/19 20:47:51 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/d5f79556-1140-45ed-8714-e8dfc103b456/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/d5f79556-1140-45ed-8714-e8dfc103b456/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/05/19 20:47:51 the binding /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456
# >>>   2021/05/19 20:47:51 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,d5f79556-1140-45ed-8714-e8dfc103b456,-m,56009m,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.batchai.envlist,--cgroup-parent=/d5f79556-1140-45ed-8714-e8dfc103b456/,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456,-v,/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd,-v,/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs
# >>>   2021/05/19 20:47:51 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name d5f79556-1140-45ed-8714-e8dfc103b456 -m 56009m -w /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/config/.batchai.envlist --cgroup-parent=/d5f79556-1140-45ed-8714-e8dfc103b456/ --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456:/mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456 -v /mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd -v /mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs:/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/certs -d -it --privileged --net=host mlopse1388ade.azurecr.io/azureml/azureml_777d58e1f33827e3873cd78466257dcc
# >>>   2021/05/19 20:47:51 Check if container d5f79556-1140-45ed-8714-e8dfc103b456 already exist exited with 0,
# >>>
# >>>   2021/05/19 20:47:51 Check if container d5f79556-1140-45ed-8714-e8dfc103b456 already exist exited with 0,
# >>>
# >>>   2021/05/19 20:47:51 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/19 20:47:51 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/19 20:47:51 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e8b7ebd35dc58a0b13557efa19b0ec61-4d871e1fc78ebfbf-01 -sshRequired=false]
# >>>   2021/05/19 20:47:51 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e8b7ebd35dc58a0b13557efa19b0ec61-4d871e1fc78ebfbf-01 -sshRequired=false]
# >>>   2021/05/19 20:47:52 Container ssh is not required for job type.
# >>>   2021/05/19 20:47:52 Starting docker container succeeded.
# >>>   2021/05/19 20:47:52 Starting docker container succeeded.
# >>>   2021/05/19 20:47:52 Disk space after starting docker container: 378469MB
# >>>   2021/05/19 20:47:52 Begin execution of runSpecialJobTask
# >>>   2021/05/19 20:47:52 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs
# >>>   2021/05/19 20:47:52 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_f56354669bb7d4c82aeb289ec6d61f97/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a0bc62b2-c5d3-4175-928e-79ab648193b6","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/19 20:47:52 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs/65_job_prep-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# >>>   2021/05/19 20:47:52 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/azureml_compute_logs/65_job_prep-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# >>>   2021/05/19 20:47:52 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456;/azureml-envs/azureml_f56354669bb7d4c82aeb289ec6d61f97/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a0bc62b2-c5d3-4175-928e-79ab648193b6","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/19 20:47:52 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/05/19 20:47:52 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-e8b7ebd35dc58a0b13557efa19b0ec61-c4f10ca9975545e1-01 -t d5f79556-1140-45ed-8714-e8dfc103b456 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/d4604087-9ac5-43e8-bc08-419119261988/job-1/d5f79556-1140-45ed-8_c453a36a-ec6f-4d24-a85e-7704ac6fa394/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456;/azureml-envs/azureml_f56354669bb7d4c82aeb289ec6d61f97/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/d5f79556-1140-45ed-8714-e8dfc103b456/mounts/workspaceblobstore/azureml/d5f79556-1140-45ed-8714-e8dfc103b456-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a0bc62b2-c5d3-4175-928e-79ab648193b6","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/19 20:47:53 Attempt 1 of http call to https://eastus.api.azureml.ms/history/v1.0/private/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourceGroups/MLOpsWorkshop/providers/Microsoft.MachineLearningServices/workspaces/mlops/runs/d5f79556-1140-45ed-8714-e8dfc103b456/spans
# >>>   2021/05/19 20:47:58 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:52.891937] Entering job preparation.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.199849] Starting job preparation.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.199896] Extracting the control code.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.218705] fetching and extracting the control code on master node.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.218741] Starting extract_project.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.218791] Starting to extract zip file.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.710479] Finished extracting zip file.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.853662] Using urllib.request Python 3.0 or later
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.853732] Start fetching snapshots.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.853780] Start fetching snapshot.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:54.853801] Retrieving project from snapshot: a0bc62b2-c5d3-4175-928e-79ab648193b6
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 56
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.483345] Finished fetching snapshot.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.483408] Finished fetching snapshots.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.483417] Finished extract_project.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.494257] Finished fetching and extracting the control code.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.498229] downloadDataStore - Download from datastores if requested.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.499413] Start run_history_prep.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:57.562305] Entering context manager injector.
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: Acquired lockfile /tmp/d5f79556-1140-45ed-8714-e8dfc103b456-datastore.lock to downloading input data references
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:58.064696] downloadDataStore completed
# >>>   2021/05/19 20:47:58 runSpecialJobTask: preparation: [2021-05-19T20:47:58.067752] Job preparation is complete.
# >>>   2021/05/19 20:47:58 Execution of runSpecialJobTask completed
# >>>   2021/05/19 20:47:58 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/05/19 20:47:58 Process Exiting with Code:  0
# >>>   2021/05/19 20:47:59 All App Insights Logs was send successfully
# >>>
# 2021-05-19T20:47:59Z 127.0.0.1 slots=8 max-slots=8
# 2021-05-19T20:47:59Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt
# ===============================================================================================================
# [2021-05-19T20:48:06.790163] Entering job release
# [2021-05-19T20:48:07.938258] Starting job release
# [2021-05-19T20:48:07.943969] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 155
# [2021-05-19T20:48:07.944658] job release stage : upload_datastore starting...
# [2021-05-19T20:48:07.945015] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-19T20:48:07.947616] job release stage : execute_job_release starting...
# [2021-05-19T20:48:07.959072] job release stage : copy_batchai_cached_logs starting...
# [2021-05-19T20:48:07.959609] job release stage : copy_batchai_cached_logs completed...
# [2021-05-19T20:48:07.960835] Entering context manager injector.
# [2021-05-19T20:48:07.985417] job release stage : upload_datastore completed...
# [2021-05-19T20:48:08.101441] job release stage : execute_job_release completed...
# [2021-05-19T20:48:08.116306] job release stage : send_run_telemetry starting...
# [2021-05-19T20:48:08.312822] get vm size and vm region successfully.
# [2021-05-19T20:48:08.481947] get compute meta data successfully.
# [2021-05-19T20:48:08.707084] post artifact meta request successfully.
# [2021-05-19T20:48:08.760612] upload compute record artifact successfully.
# [2021-05-19T20:48:08.760707] job release stage : send_run_telemetry completed...
# [2021-05-19T20:48:08.761196] Job release is complete
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': 'd5f79556-1140-45ed-8714-e8dfc103b456', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-05-19T20:47:48.966165Z', 'endTimeUtc': '2021-05-19T20:48:49.062932Z', 'properties': {'ContentSnapshotId': 'a0bc62b2-c5d3-4175-928e-79ab648193b6', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c1631a56-c323-411b-9880-5bfb2317e400', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '69f042e0', 'azureml.pipelinerunid': 'e104aaf3-0c5a-4d82-9d94-95eb7f6b468e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_outputs'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'automl', 'dataReferences': {'outputs': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/ac02198e-ff79-44b4-8d60-65627366c535/outputs', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'driver-training', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}, 'pip', 'scikit-learn', 'lightgbm'], 'name': 'azureml_f56354669bb7d4c82aeb289ec6d61f97'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.d5f79556-1140-45ed-8714-e8dfc103b456/azureml-logs/55_azureml-execution-tvmps_b17f9ce8e6aea49a4858c02313a900d001f357c8d41296468f05cba4e54bfe58_d.txt?sv=2019-02-02&sr=b&sig=crtXdH5CjX1tTH5xVFH1p6mxdUVS%2B5VliRUr%2BRFLhGw%3D&st=2021-05-19T20%3A38%3A13Z&se=2021-05-20T04%3A48%3A13Z&sp=r', 'azureml-logs/65_job_prep-tvmps_b17f9ce8e6aea49a4858c02313a90 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e104aaf3-0c5a-4d82-9d94-95eb7f6b468e', 'status': 'Completed', 'startTimeUtc': '2021-05-19T20:41:24.704969Z', 'endTimeUtc': '2021-05-19T20:48:51.040608Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.e104aaf3-0c5a-4d82-9d94-95eb7f6b468e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=U9ceVejldFTel2HSKc4PwkKUPaINYhGm4rD%2FeKnpQZk%3D&st=2021-05-19T20%3A31%3A28Z&se=2021-05-20T04%3A41%3A28Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.e104aaf3-0c5a-4d82-9d94-95eb7f6b468e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=97rpmjU%2FSlPaESbztp1roKvPB%2F7VgibRQEIjzEzE3TQ%3D&st=2021-05-19T20%3A31%3A28Z&se=2021-05-20T04%3A41%3A28Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.e104aaf3-0c5a-4d82-9d94-95eb7f6b468e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=3enfprknf7C7TO6zQqZK%2BuF3fuh0AwkTgCmnXWRXX8A%3D&st=2021-05-19T20%3A31%3A28Z&se=2021-05-20T04%3A41%3A28Z&sp=r'}, 'submittedBy': 'Dave Wentzel'}
# 'Finished'

# %%
# Print the model name, version, tag, and properties
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# driver_model version: 3
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 4
#
#
# driver_model.pkl version: 3
#
#
# driver_model version: 2
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 2
#
#
# driver_model version: 1
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 1
#
#
# compliance-classifier version: 17
# 	 type : classification
# 	 run_id : 0767a613-e8c2-4811-ae6b-64369e340725
# 	 build_number : 20201217.1
#
#
# BikeBuyer.mml version: 4
#
#
# AutoMLb9be0a22f28 version: 1
#
#
# compliance-classifier version: 16
# 	 type : classification
# 	 run_id : a7eb32c9-3207-4a2c-865a-d65fba7946ba
# 	 build_number : 20201119.1
#
#
# compliance-classifier version: 15
# 	 type : classification
# 	 run_id : 8e84d5f5-54c9-48c9-b733-9bbbcd86558b
# 	 build_number : 20201118.1
#
#
# IBM_attrition_model version: 1
# 	 area : HR
# 	 type : attrition
#
#
# AutoML015fd913221 version: 1
#
#
# diabetes_model version: 1
# 	 Training context : Inline Training
# 	 AUC : 0.8857431111811085
# 	 Accuracy : 0.9002222222222223
#
#
# glove-text-classifier version: 1
# 	 type : classification
# 	 run_id : glove-embeddings-classifier_1597854176_900c5cea
#
#
# compliance-classifier version: 14
# 	 type : classification
# 	 run_id : 3886cc4f-8a9d-4608-abea-c588a9074912
# 	 build_number : 20200428.2
#
#
# compliance-classifier version: 13
# 	 type : classification
# 	 run_id : 36b88b87-4c5e-4d64-8fa3-ae721eda608d
# 	 build_number : 20200428.1
#
#
# compliance-classifier version: 12
# 	 type : classification
# 	 run_id : 46b16ce1-7719-4faa-84ae-6d6a4835da08
# 	 build_number : 20200427.1
#
#
# compliance-classifier-qvc version: 1
# 	 type : classification
# 	 run_id : deep-learning-qvc_1587989276_00ba8da2
#
#
# BikeBuyer.mml version: 3
#
#
# compliance-classifier version: 11
# 	 type : classification
# 	 run_id : 8c546c17-d0a9-43dc-92c6-c464fdfe68e2
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 10
# 	 type : classification
# 	 run_id : 3d1df6b1-fd5e-42e1-9021-44038a2aeabd
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 9
# 	 type : classification
# 	 run_id : 22e820b2-1015-4ac2-88d4-c80eed9e0006
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 8
# 	 type : classification
# 	 run_id : 1d751a7d-5470-473a-8e9b-5b22be5fb2bb
# 	 build_number : 20191028.1
#
#
# compliance-classifier version: 7
# 	 type : classification
# 	 run_id : db72b465-9ae9-4e22-8a3c-22b81e09478b
# 	 build_number : 20191025.1
#
#
# compliance-classifier version: 6
# 	 type : classification
# 	 run_id : 5c59dcd9-f23b-4abf-a1b5-af151927f0e7
# 	 build_number : 20191024.4
#
#
# compliance-classifier version: 5
# 	 type : classification
# 	 run_id : 5c7a146e-bb1a-40a8-a3a0-ac1f953205f4
# 	 build_number : 20191024.3
#
#
# compliance-classifier version: 4
# 	 type : classification
# 	 run_id : 1a7ba8f6-f615-4ec2-8c1f-6926c2517234
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 3
# 	 type : classification
# 	 run_id : 138fdae4-b92f-494d-8d63-ed884f655332
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 2
#
#
# compliance-classifier version: 1
# 	 type : classification
# 	 run_id : deep-learning_1571935012_a8c321f6
#
#
# BikeBuyer.mml version: 2
#
#
# BikeBuyer.mml version: 1
