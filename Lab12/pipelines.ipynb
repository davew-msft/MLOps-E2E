# %% [markdown]
# You should already have a train.py, driver_training.py, and a parameters.json in an experiment folder. These resources will be used as the first step in the Machine Learning pipeline created and run later in this notebook.

# %%
# !pwd
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/davew202105/code/git/MLOps-E2E-sdkv2/Lab12

# %%
# Set the folder for the experiment files used in Challenge 2
training_folder = 'driver-training'

# %% [markdown]
# ## register_model.py
# This script loads the model from where it was saved, and then registers it in the workspace. This will be the second step in the pipeline. The script is written to the experiment folder from this notebook for convenience.
#
# Note:  if we decide not to use AMLS pipelines and just want to use a more DevOps-centric approach (using gh actions or azdo pipelines instead of AMLS pipelines), we can.

# %%
# %%writefile $training_folder/register_model.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="driver_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_name = 'driver_model'
model_file = model_folder + "/" + model_name + ".pkl"

# Get metrics for registration
## TODO
## HINT: Try storing the metrics in the parent run, which will be
##       accessible during both the training and registration
##       child runs using the 'run.parent' API.
## See https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py#parent

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'driver_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing driver-training/register_model.py

# %% [markdown]
# ## Create an Azure Machine Learning Pipeline to Run the Scripts as a Pipeline
#
# See [this tutorial](https://github.com/MicrosoftDocs/mslearn-aml-labs/blob/master/05-Creating_a_Pipeline.ipynb) for a starting point
#
# Use the scikit-learn and lightgbm conda packages

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace
ws = Workspace.from_config()

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "automl"  #changeme

# Verify that the compute cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           vm_priority='lowpriority', 
                                                           max_nodes=4)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

env_name = training_folder + '-env'

# Create a Python environment for the experiment
env = Environment(env_name)
env.python.user_managed_dependencies = False  # Let Azure ML manage dependencies
env.docker.enabled = True                     # Use a docker container

# Create the pip and conda package dependencies
dependencies = CondaDependencies.create(
    conda_packages=['scikit-learn', 'pandas'],
    pip_packages=['azureml-sdk','lightgbm'])

# Add the package dependencies to the Python environment for the experiment
env.python.conda_dependencies = dependencies

# Register the environment 
env.register(workspace=ws)
registered_env = Environment.get(ws, env_name)

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Assign the target of the runconfig object to the cluster created above  
pipeline_run_config.target = pipeline_cluster

# Assign the environment of the runconfig object to the registered environment
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Run configuration created.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData(
    "model_folder", 
    datastore=ws.get_default_datastore())

# Create Estimator to train the model like we did before
estimator = Estimator(
    source_directory=training_folder,
    compute_target = pipeline_cluster,
    environment_definition=pipeline_run_config.environment,
    entry_script='driver_training.py')

# Create Step 1, which runs the estimator to train the model
train_step = EstimatorStep(
    name = "Train Model",
    estimator=estimator, 
    estimator_entry_script_arguments=['--output_folder', model_folder],
    outputs=[model_folder],
    compute_target = pipeline_cluster,
    allow_reuse = True)

# Create Step 2, which runs the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = training_folder,
                                script_name = "register_model.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# 'Estimator' is deprecated. Please use 'ScriptRunConfig' from 'azureml.core.script_run_config' with your own defined environment or an Azure ML curated environment.
# 'EstimatorStep' is deprecated. Please use 'CommandStep' from 'azureml.pipeline.steps.CommandStep' instead. For an example see https://github.com/Azure/MachineLearningNotebooks/blob/master/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-commandstep.ipynb.
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline, which contains Step 1 & 2
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'driver-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()

# try monitoring this from the Azure portal as well.  
# make sure you understand approximately what this is doing
# Out:
# 'EstimatorStep' is deprecated. Please use 'CommandStep' from 'azureml.pipeline.steps.CommandStep' instead. For an example see https://github.com/Azure/MachineLearningNotebooks/blob/master/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-commandstep.ipynb.
# Pipeline is built.
# Created step Train Model [5a0d70b8][37131c3c-7720-404b-98fb-8dc06b1c8178], (This step will run and generate new outputs)
# Created step Register Model [cd5139c5][e2d4d68c-8c17-47fe-85b8-bdfb3640cb1e], (This step will run and generate new outputs)
# Submitted PipelineRun de66bf8b-fa49-4584-9184-d1c676565692
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/de66bf8b-fa49-4584-9184-d1c676565692?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: de66bf8b-fa49-4584-9184-d1c676565692
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/de66bf8b-fa49-4584-9184-d1c676565692?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: db0a8f0f-3511-495b-88cf-137a698bd522
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/db0a8f0f-3511-495b-88cf-137a698bd522?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/05/13 17:56:06 Downloading source code...
# 2021/05/13 17:56:07 Finished downloading source code
# 2021/05/13 17:56:08 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/13 17:56:08 Successfully set up Docker network: acb_default_network
# 2021/05/13 17:56:08 Setting up Docker configuration...
# 2021/05/13 17:56:09 Successfully set up Docker configuration
# 2021/05/13 17:56:09 Logging in to registry: mlopse1388ade.azurecr.io
# 2021/05/13 17:56:10 Successfully logged into mlopse1388ade.azurecr.io
# 2021/05/13 17:56:10 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/13 17:56:10 Scanning for dependencies...
# 2021/05/13 17:56:11 Successfully scanned dependencies
# 2021/05/13 17:56:11 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in aff895ecb73e
# Removing intermediate container aff895ecb73e
#  ---> a2d50aba0017
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 36418752fc74
# Removing intermediate container 36418752fc74
#  ---> 34d9ef5bff59
# Step 4/18 : WORKDIR /
#  ---> Running in 7b06a6956878
# Removing intermediate container 7b06a6956878
#  ---> 0c193aab8dfc
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 96b712128e13
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in c98990671a74
# Removing intermediate container c98990671a74
#  ---> 1b5b8fd8a0a6
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> b519fb59b750
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in d1025ae59e93
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########4  |  84%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####5     |  56%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #6         |  16%
# mkl-2019.4           | 204.1 MB  | ##1        |  21%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ###1       |  32%
# mkl-2019.4           | 204.1 MB  | ###6       |  36%
# mkl-2019.4           | 204.1 MB  | ####       |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  45%
# mkl-2019.4           | 204.1 MB  | ####9      |  49%
# mkl-2019.4           | 204.1 MB  | #####3     |  54%
# mkl-2019.4           | 204.1 MB  | #####8     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######8    |  68%
# mkl-2019.4           | 204.1 MB  | #######2   |  73%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########1  |  81%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #7         |  17%
# python-3.6.2         | 27.0 MB   | ####8      |  48%
# python-3.6.2         | 27.0 MB   | #######4   |  75%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ######1    |  61%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ######1    |  61%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #######    |  70%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##9        |  30%
# scipy-1.5.2          | 18.5 MB   | ########   |  80%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #####3     |  54%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #####      |  50%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.xthl3o_k.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk~=1.27.0
#   Downloading azureml_sdk-1.27.0-py3-none-any.whl (4.4 kB)
# Collecting lightgbm
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting azureml-train~=1.27.0
#   Downloading azureml_train-1.27.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-core~=1.27.0
#   Downloading azureml_core-1.27.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.27.0
#   Downloading azureml_dataset_runtime-1.27.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-train-automl-client~=1.27.0
#   Downloading azureml_train_automl_client-1.27.0-py3-none-any.whl (120 kB)
# Collecting azureml-pipeline~=1.27.0
#   Downloading azureml_pipeline-1.27.0-py3-none-any.whl (3.7 kB)
# Requirement already satisfied, skipping upgrade: wheel in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied, skipping upgrade: numpy in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.22.0 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (0.23.2)
# Requirement already satisfied, skipping upgrade: scipy in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (1.5.2)
# Collecting azureml-train-core~=1.27.0
#   Downloading azureml_train_core-1.27.0-py3-none-any.whl (8.6 MB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-sdk~=1.27.0->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 1)) (2020.1)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-sdk~=1.27.0->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 1)) (2.8.1)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting azureml-dataprep<2.15.0a,>=2.14.0a
#   Downloading azureml_dataprep-2.14.2-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-telemetry~=1.27.0
#   Downloading azureml_telemetry-1.27.0-py3-none-any.whl (30 kB)
# Collecting azureml-automl-core~=1.27.0
#   Downloading azureml_automl_core-1.27.0-py3-none-any.whl (201 kB)
# Collecting azureml-pipeline-steps~=1.27.0
#   Downloading azureml_pipeline_steps-1.27.0-py3-none-any.whl (69 kB)
# Collecting azureml-pipeline-core~=1.27.0
#   Downloading azureml_pipeline_core-1.27.0-py3-none-any.whl (310 kB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from scikit-learn!=0.22.0->lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from scikit-learn!=0.22.0->lightgbm->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 2)) (2.1.0)
# Collecting azureml-train-restclients-hyperdrive~=1.27.0
#   Downloading azureml_train_restclients_hyperdrive-1.27.0-py3-none-any.whl (19 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.7.3->azureml-core~=1.27.0->azureml-sdk~=1.27.0->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 1)) (1.15.0)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.27.0->azureml-sdk~=1.27.0->-r /azureml-environment-setup/condaenv.xthl3o_k.requirements.txt (line 1)) (2020.6.20)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting azureml-dataprep-rslex<1.13.0a,>=1.12.0dev0
#   Downloading azureml_dataprep_rslex-1.12.1-cp36-cp36m-manylinux1_x86_64.whl (9.6 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.13.0-py2.py3-none-any.whl (133 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=81b1f37e6f27df87519d89c6b18136b6eba110db07200e39a76bcf8315f7cba1
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: pycparser, cffi, cryptography, contextlib2, jmespath, backports.weakref, backports.tempfile, PyJWT, pathspec, oauthlib, urllib3, chardet, idna, requests, requests-oauthlib, isodate, msrest, azure-common, adal, msrestazure, azure-mgmt-storage, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-resource, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-graphrbac, azure-mgmt-authorization, pyasn1, pyopenssl, ndg-httpsclient, websocket-client, docker, ruamel.yaml.clib, ruamel.yaml, jeepney, SecretStorage, azureml-core, applicationinsights, azureml-telemetry, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-train, azureml-dataprep-rslex, azure-core, msal, portalocker, msal-extensions, azure-identity, cloudpickle, azureml-dataprep-native, distro, dotnetcore2, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk, lightgbm
# Successfully installed PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.13.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.27.0 azureml-core-1.27.0 azureml-dataprep-2.14.2 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.12.1 azureml-dataset-runtime-1.27.0 azureml-pipeline-1.27.0 azureml-pipeline-core-1.27.0 azureml-pipeline-steps-1.27.0 azureml-sdk-1.27.0 azureml-telemetry-1.27.0 azureml-train-1.27.0 azureml-train-automl-client-1.27.0 azureml-train-core-1.27.0 azureml-train-restclients-hyperdrive-1.27.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.7 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 fusepy-3.0.1 idna-2.10 importlib-metadata-4.0.1 isodate-0.6.0 jeepney-0.6.0 jmespath-0.10.0 jsonpickle-2.0.0 lightgbm-3.2.1 msal-1.11.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.4 websocket-client-0.59.0 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container d1025ae59e93
#  ---> f9b9b79239ea
# Step 9/18 : ENV PATH /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/bin:$PATH
#  ---> Running in c260cd73b47b
# Removing intermediate container c260cd73b47b
#  ---> 100fa2c3da33
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> e5a2b6ebab6a
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 29ff4025a2b9
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a
#  ---> Running in 9d2117d8f792
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 9d2117d8f792
#  ---> 3317139a189f
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a
#  ---> Running in a3a9f7c00366
# Removing intermediate container a3a9f7c00366
#  ---> 63d8e2f363a0
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/lib:$LD_LIBRARY_PATH
#  ---> Running in 424d95619294
# Removing intermediate container 424d95619294
#  ---> 1ff0b2729a70
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 49129e89b95c
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in fdb15786468d
# Removing intermediate container fdb15786468d
#  ---> 3c9ea930e639
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 2c648ebc43bd
# Removing intermediate container 2c648ebc43bd
#  ---> 23c7cf6d3d4a
# Step 18/18 : CMD ["bash"]
#  ---> Running in dc186990532b
# Removing intermediate container dc186990532b
#  ---> 0e5abcfaf876
# Successfully built 0e5abcfaf876
# Successfully tagged mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# Successfully tagged mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:1
# 2021/05/13 18:00:11 Successfully executed container: acb_step_0
# 2021/05/13 18:00:11 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/13 18:00:11 Pushing image: mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:1, attempt 1
# The push refers to repository [mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f]
# 287d1e9d8926: Preparing
# 72a8f5a30bfc: Preparing
# c6190da8d84d: Preparing
# 636a883789ba: Preparing
# 7b0860e237ae: Preparing
# 8985c73650b6: Preparing
# f5158dd2c3c4: Preparing
# d26fd2f05799: Preparing
# df903ffa0555: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 8985c73650b6: Waiting
# f5158dd2c3c4: Waiting
# d26fd2f05799: Waiting
# df903ffa0555: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# 287d1e9d8926: Pushed
# 636a883789ba: Pushed
# 72a8f5a30bfc: Pushed
# c6190da8d84d: Pushed
# 8985c73650b6: Pushed
# d26fd2f05799: Pushed
# f5158dd2c3c4: Pushed
# df903ffa0555: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 0d34930f20d5: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# 4441896e1280: Pushed
# a64fe594a899: Pushed
# e4a0bf630548: Pushed
# 935c56d8b3f9: Pushed
#
# 7b0860e237ae: Pushed
# 1: digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17 size: 4721
# 2021/05/13 18:02:46 Successfully pushed image: mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:1
# 2021/05/13 18:02:46 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/13 18:02:46 Pushing image: mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest, attempt 1
# The push refers to repository [mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f]
# 287d1e9d8926: Preparing
# 72a8f5a30bfc: Preparing
# c6190da8d84d: Preparing
# 636a883789ba: Preparing
# 7b0860e237ae: Preparing
# 8985c73650b6: Preparing
# f5158dd2c3c4: Preparing
# d26fd2f05799: Preparing
# df903ffa0555: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 8985c73650b6: Waiting
# f5158dd2c3c4: Waiting
# d26fd2f05799: Waiting
# df903ffa0555: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 7b0860e237ae: Layer already exists
# 287d1e9d8926: Layer already exists
# 636a883789ba: Layer already exists
# c6190da8d84d: Layer already exists
# 72a8f5a30bfc: Layer already exists
# df903ffa0555: Layer already exists
# f5158dd2c3c4: Layer already exists
# d26fd2f05799: Layer already exists
# 8985c73650b6: Layer already exists
# 3f3f8889d538: Layer already exists
# 4441896e1280: Layer already exists
# 420340de7040: Layer already exists
# a64fe594a899: Layer already exists
# 0d34930f20d5: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# 18c9012f327d: Layer already exists
# e6feec0db89a: Layer already exists
# 5276d2b930fc: Layer already exists
# e4a0bf630548: Layer already exists
# 697949baa658: Layer already exists
# 935c56d8b3f9: Layer already exists
# latest: digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17 size: 4721
# 2021/05/13 18:02:53 Successfully pushed image: mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# 2021/05/13 18:02:53 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 240.798101)
# 2021/05/13 18:02:53 Populating digests for step ID: acb_step_0...
# 2021/05/13 18:02:57 Successfully populated digests for step ID: acb_step_0
# 2021/05/13 18:02:57 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 155.219315)
# 2021/05/13 18:02:57 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.593510)
# 2021/05/13 18:02:57 The following dependencies were found:
# 2021/05/13 18:02:57
# - image:
#     registry: mlopse1388ade.azurecr.io
#     repository: azureml/azureml_c1e88a77561229d93d511c1f24b5f61f
#     tag: latest
#     digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: mlopse1388ade.azurecr.io
#     repository: azureml/azureml_c1e88a77561229d93d511c1f24b5f61f
#     tag: "1"
#     digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
#
# Run ID: ca11 was successful after 6m52s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# ========================================================================================================================
# 2021-05-13T18:06:33Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/db0a8f0f-3511-495b-88cf-137a698bd522/mounts/workspaceblobstore
# 2021-05-13T18:06:34Z Starting output-watcher...
# 2021-05-13T18:06:34Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-13T18:06:34Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-13T18:06:34Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_c1e88a77561229d93d511c1f24b5f61f
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 33cd71f7da65: Pulling fs layer
# 574f361512d6: Waiting
# ce44c91f3fed: Pulling fs layer
# db4d1e2d7079: Waiting
# 9aca07d7eb31: Pulling fs layer
# 897c56569bba: Pulling fs layer
# 02e4622827d3: Pulling fs layer
# 20267cd5d7e4: Pulling fs layer
# e544ee0f522d: Waiting
# dbd5c35978dc: Pulling fs layer
# 204ca16f8377: Pulling fs layer
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# e4f1806cb625: Pulling fs layer
# 5fba3bd4a2c4: Waiting
# ce44c91f3fed: Waiting
# 9aca07d7eb31: Waiting
# 20267cd5d7e4: Waiting
# 897c56569bba: Waiting
# 33cd71f7da65: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# dbd5c35978dc: Waiting
# e4f1806cb625: Waiting
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# 5fba3bd4a2c4: Download complete
# da005f826951: Download complete
# 33cd71f7da65: Download complete
# 897c56569bba: Verifying Checksum
# 897c56569bba: Download complete
# ce44c91f3fed: Download complete
# 9aca07d7eb31: Download complete
# 20267cd5d7e4: Download complete
# 204ca16f8377: Verifying Checksum
# 204ca16f8377: Download complete
# dbd5c35978dc: Verifying Checksum
# dbd5c35978dc: Download complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# e4f1806cb625: Download complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# 33cd71f7da65: Pull complete
# ce44c91f3fed: Pull complete
# 9aca07d7eb31: Pull complete
# 897c56569bba: Pull complete
# 02e4622827d3: Verifying Checksum
# 02e4622827d3: Download complete
# 02e4622827d3: Pull complete
# 20267cd5d7e4: Pull complete
# dbd5c35978dc: Pull complete
# 204ca16f8377: Pull complete
# e4f1806cb625: Pull complete
# Digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17
# Status: Downloaded newer image for mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# 2021-05-13T18:06:59Z Check if container db0a8f0f-3511-495b-88cf-137a698bd522 already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# ===============================================================================================================
# [2021-05-13T18:07:30.892228] Entering job preparation.
# [2021-05-13T18:07:32.362569] Starting job preparation.
# [2021-05-13T18:07:32.362621] Extracting the control code.
# [2021-05-13T18:07:32.383566] fetching and extracting the control code on master node.
# [2021-05-13T18:07:32.383617] Starting extract_project.
# [2021-05-13T18:07:32.383670] Starting to extract zip file.
# [2021-05-13T18:07:32.898441] Finished extracting zip file.
# [2021-05-13T18:07:33.040401] Using urllib.request Python 3.0 or later
# [2021-05-13T18:07:33.040463] Start fetching snapshots.
# [2021-05-13T18:07:33.040509] Start fetching snapshot.
# [2021-05-13T18:07:33.040528] Retrieving project from snapshot: 3274deda-0c1b-48ed-b67a-470dee9df359
# Starting the daemon thread to refresh tokens in background for process with pid = 54
# [2021-05-13T18:07:36.175050] Finished fetching snapshot.
# [2021-05-13T18:07:36.175096] Finished fetching snapshots.
# [2021-05-13T18:07:36.175103] Finished extract_project.
# [2021-05-13T18:07:36.190631] Finished fetching and extracting the control code.
# [2021-05-13T18:07:36.194742] downloadDataStore - Download from datastores if requested.
# [2021-05-13T18:07:36.195932] Start run_history_prep.
# [2021-05-13T18:07:36.254630] Entering context manager injector.
# Acquired lockfile /tmp/db0a8f0f-3511-495b-88cf-137a698bd522-datastore.lock to downloading input data references
# [2021-05-13T18:07:37.374681] downloadDataStore completed
# [2021-05-13T18:07:37.378820] Job preparation is complete.
#
# Streaming azureml-logs/75_job_post-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# ===============================================================================================================
# [2021-05-13T18:08:01.926404] Entering job release
# [2021-05-13T18:08:03.543239] Starting job release
# [2021-05-13T18:08:03.557901] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 206
# [2021-05-13T18:08:03.566001] job release stage : upload_datastore starting...
# [2021-05-13T18:08:03.571874] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-13T18:08:03.571931] job release stage : execute_job_release starting...
# [2021-05-13T18:08:03.572880] job release stage : copy_batchai_cached_logs starting...
# [2021-05-13T18:08:03.572929] job release stage : copy_batchai_cached_logs completed...
# [2021-05-13T18:08:03.582270] Entering context manager injector.
# [2021-05-13T18:08:03.605954] job release stage : upload_datastore completed...
# [2021-05-13T18:08:03.751431] job release stage : send_run_telemetry starting...
# [2021-05-13T18:08:03.795912] job release stage : execute_job_release completed...
# [2021-05-13T18:08:03.919387] get vm size and vm region successfully.
# [2021-05-13T18:08:04.217122] get compute meta data successfully.
# [2021-05-13T18:08:04.437924] post artifact meta request successfully.
# [2021-05-13T18:08:04.484130] upload compute record artifact successfully.
# [2021-05-13T18:08:04.484259] job release stage : send_run_telemetry completed...
# [2021-05-13T18:08:04.484870] Job release is complete
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'db0a8f0f-3511-495b-88cf-137a698bd522', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-05-13T18:06:31.863207Z', 'endTimeUtc': '2021-05-13T18:08:14.992178Z', 'properties': {'ContentSnapshotId': '3274deda-0c1b-48ed-b67a-470dee9df359', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '37131c3c-7720-404b-98fb-8dc06b1c8178', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '5a0d70b8', 'azureml.pipelinerunid': 'de66bf8b-fa49-4584-9184-d1c676565692', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'driver_training.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'automl', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/db0a8f0f-3511-495b-88cf-137a698bd522/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'driver-training-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.27.0', 'lightgbm']}, 'scikit-learn', 'pandas'], 'name': 'azureml_2c3256799969ee2f2a2b7b78b6af812a'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.db0a8f0f-3511-495b-88cf-137a698bd522/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=0P1dpmu2EMzPCJ5kyEYv9qOjnM4yD4PfOUig26QtGAg%3D&st=2021-05-13T17%3A58%3A05Z&se=2021-05-14T02%3A08%3A05Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.db ...
#
#
#
#
# StepRunId: 721b007b-8b5a-4c1b-932e-9d21e213118c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/721b007b-8b5a-4c1b-932e-9d21e213118c?wsid=/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourcegroups/MLOpsWorkshop/workspaces/mlops&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# ========================================================================================================================
# 2021-05-13T18:08:33Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore
# 2021-05-13T18:08:34Z Starting output-watcher...
# 2021-05-13T18:08:34Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-13T18:08:34Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-13T18:08:34Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_c1e88a77561229d93d511c1f24b5f61f
# Digest: sha256:6bc084046817d0d9c6e42f1bc306b9618476d81094d5cb053e1a4aba4e1f6a17
# Status: Image is up to date for mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# mlopse1388ade.azurecr.io/azureml/azureml_c1e88a77561229d93d511c1f24b5f61f:latest
# 2021-05-13T18:08:34Z Check if container 721b007b-8b5a-4c1b-932e-9d21e213118c already exist exited with 0,
#
# 883b1872eabd8045adacf378612c1275f0027543dd1d8def56c27d0484ccbd34
# 2021-05-13T18:08:35Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-05-13T18:08:35Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-badacf8aa62b3b45230ff2bbbfd890e8-45967f1abd1ea0df-01 -sshRequired=false]
# 2021/05/13 18:08:35 Starting App Insight Logger for task:  containerSetup
# 2021/05/13 18:08:35 Version: 3.0.01591.0003 Branch: .SourceBranch Commit: 5e69378
# 2021/05/13 18:08:35 Entered ContainerSetupTask - Preparing infiniband
# 2021/05/13 18:08:35 Starting infiniband setup
# 2021/05/13 18:08:35 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/13 18:08:35 Returning Python Version as 3.6
# 2021/05/13 18:08:35 VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/13 18:08:35 VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-05-13T18:08:35Z VMSize: standard_d13_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/13 18:08:35 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/05/13 18:08:35 Not setting up Infiniband in Container
# 2021/05/13 18:08:35 Not setting up Infiniband in Container
# 2021-05-13T18:08:35Z Not setting up Infiniband in Container
# 2021/05/13 18:08:35 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/13 18:08:35 Returning Python Version as 3.6
# 2021/05/13 18:08:35 sshd inside container not required for job, skipping setup.
# 2021/05/13 18:08:35 All App Insights Logs was send successfully
# 2021/05/13 18:08:35 App Insight Client has already been closed
# 2021/05/13 18:08:35 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-05-13T18:08:35Z Starting docker container succeeded.
# 2021-05-13T18:08:43Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2021/05/13 18:08:32 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/05/13 18:08:32 Version: 3.0.01591.0003 Branch: .SourceBranch Commit: 5e69378
# >>>   2021/05/13 18:08:32 runtime.GOOS linux
# >>>   2021/05/13 18:08:32 Checking if '/tmp' exists
# >>>   2021/05/13 18:08:32 Reading dyanamic configs
# >>>   2021/05/13 18:08:32 Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=gCpFfTbL8hPl%2BzV43hBdfOZC4SuKqZoJraIo10S4%2FYw%3D
# ...
# >>>   2021/05/13 18:08:34 Check if container 721b007b-8b5a-4c1b-932e-9d21e213118c already exist exited with 0,
# >>>
# >>>   2021/05/13 18:08:34 Check if container 721b007b-8b5a-4c1b-932e-9d21e213118c already exist exited with 0,
# >>>
# >>>   2021/05/13 18:08:35 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/13 18:08:35 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/13 18:08:35 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-badacf8aa62b3b45230ff2bbbfd890e8-45967f1abd1ea0df-01 -sshRequired=false]
# >>>   2021/05/13 18:08:35 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-badacf8aa62b3b45230ff2bbbfd890e8-45967f1abd1ea0df-01 -sshRequired=false]
# >>>   2021/05/13 18:08:35 Container ssh is not required for job type.
# >>>   2021/05/13 18:08:35 Starting docker container succeeded.
# >>>   2021/05/13 18:08:35 Starting docker container succeeded.
# >>>   2021/05/13 18:08:35 Disk space after starting docker container: 378465MB
# >>>   2021/05/13 18:08:35 Begin execution of runSpecialJobTask
# >>>   2021/05/13 18:08:35 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/azureml_compute_logs
# >>>   2021/05/13 18:08:35 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"3274deda-0c1b-48ed-b67a-470dee9df359","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/13 18:08:35 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/azureml_compute_logs/65_job_prep-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# >>>   2021/05/13 18:08:35 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/azureml_compute_logs/65_job_prep-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# >>>   2021/05/13 18:08:35 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/f2fc36b4-dea7-4fac-938d-4eb030dc98d5/job-1/721b007b-8b5a-4c1b-9_d0f97141-ebd3-435f-9c66-b7af696afd6d/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c;/azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"3274deda-0c1b-48ed-b67a-470dee9df359","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/13 18:08:35 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/05/13 18:08:35 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-badacf8aa62b3b45230ff2bbbfd890e8-c32bcf60e8ff7024-01 -t 721b007b-8b5a-4c1b-932e-9d21e213118c bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/f2fc36b4-dea7-4fac-938d-4eb030dc98d5/job-1/721b007b-8b5a-4c1b-9_d0f97141-ebd3-435f-9c66-b7af696afd6d/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c;/azureml-envs/azureml_2c3256799969ee2f2a2b7b78b6af812a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c/mounts/workspaceblobstore/azureml/721b007b-8b5a-4c1b-932e-9d21e213118c-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"3274deda-0c1b-48ed-b67a-470dee9df359","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/13 18:08:37 Attempt 1 of http call to https://eastus.api.azureml.ms/history/v1.0/private/subscriptions/52061d21-01dd-4f9e-aca9-60fff4d67ee2/resourceGroups/MLOpsWorkshop/providers/Microsoft.MachineLearningServices/workspaces/mlops/runs/721b007b-8b5a-4c1b-932e-9d21e213118c/spans
# >>>   2021/05/13 18:08:42 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:36.266393] Entering job preparation.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:37.710816] Starting job preparation.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:37.710868] Extracting the control code.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:37.730522] fetching and extracting the control code on master node.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:37.730567] Starting extract_project.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:37.730609] Starting to extract zip file.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:38.254379] Finished extracting zip file.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:38.398745] Using urllib.request Python 3.0 or later
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:38.398813] Start fetching snapshots.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:38.398867] Start fetching snapshot.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:38.398884] Retrieving project from snapshot: 3274deda-0c1b-48ed-b67a-470dee9df359
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 55
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.399435] Finished fetching snapshot.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.399487] Finished fetching snapshots.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.399494] Finished extract_project.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.410725] Finished fetching and extracting the control code.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.414472] downloadDataStore - Download from datastores if requested.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.415635] Start run_history_prep.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:41.473634] Entering context manager injector.
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: Acquired lockfile /tmp/721b007b-8b5a-4c1b-932e-9d21e213118c-datastore.lock to downloading input data references
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:42.506563] downloadDataStore completed
# >>>   2021/05/13 18:08:42 runSpecialJobTask: preparation: [2021-05-13T18:08:42.510118] Job preparation is complete.
# >>>   2021/05/13 18:08:42 Execution of runSpecialJobTask completed
# >>>   2021/05/13 18:08:42 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/05/13 18:08:42 Process Exiting with Code:  0
# >>>   2021/05/13 18:08:43 All App Insights Logs was send successfully
# >>>
# 2021-05-13T18:08:43Z 127.0.0.1 slots=8 max-slots=8
# 2021-05-13T18:08:43Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt
# ===============================================================================================================
# [2021-05-13T18:08:52.092950] Entering job release
# [2021-05-13T18:08:53.716258] Starting job release
# [2021-05-13T18:08:53.722600] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 186
# [2021-05-13T18:08:53.726712] job release stage : upload_datastore starting...
# [2021-05-13T18:08:53.734052] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-13T18:08:53.734093] job release stage : execute_job_release starting...
# [2021-05-13T18:08:53.734541] job release stage : copy_batchai_cached_logs starting...
# [2021-05-13T18:08:53.734707] job release stage : copy_batchai_cached_logs completed...
# [2021-05-13T18:08:53.735738] Entering context manager injector.
# [2021-05-13T18:08:53.756602] job release stage : upload_datastore completed...
# [2021-05-13T18:08:53.922348] job release stage : send_run_telemetry starting...
# [2021-05-13T18:08:53.935766] job release stage : execute_job_release completed...
# [2021-05-13T18:08:54.098771] get vm size and vm region successfully.
# [2021-05-13T18:08:54.295640] get compute meta data successfully.
# [2021-05-13T18:08:54.454004] post artifact meta request successfully.
# [2021-05-13T18:08:54.529898] upload compute record artifact successfully.
# [2021-05-13T18:08:54.529998] job release stage : send_run_telemetry completed...
# [2021-05-13T18:08:54.530427] Job release is complete
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '721b007b-8b5a-4c1b-932e-9d21e213118c', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-05-13T18:08:31.67149Z', 'endTimeUtc': '2021-05-13T18:09:04.773595Z', 'properties': {'ContentSnapshotId': '3274deda-0c1b-48ed-b67a-470dee9df359', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'e2d4d68c-8c17-47fe-85b8-bdfb3640cb1e', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cd5139c5', 'azureml.pipelinerunid': 'de66bf8b-fa49-4584-9184-d1c676565692', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'automl', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/db0a8f0f-3511-495b-88cf-137a698bd522/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'driver-training-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.27.0', 'lightgbm']}, 'scikit-learn', 'pandas'], 'name': 'azureml_2c3256799969ee2f2a2b7b78b6af812a'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.721b007b-8b5a-4c1b-932e-9d21e213118c/azureml-logs/55_azureml-execution-tvmps_b6fc1663069720be69413bf0d3ddc8c311005e04458c20e0f3a2c5d48001f369_d.txt?sv=2019-02-02&sr=b&sig=wX7rQjGZtTvMnEnRM4SaL%2FLd8oXTe7xeYwzw%2BUPonzA%3D&st=2021-05-13T17%3A58%3A57Z&se=2021-05-14T02%3A08%3A57Z&sp=r', 'azureml-logs/65_job_prep-tvmps_b6fc16 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'de66bf8b-fa49-4584-9184-d1c676565692', 'status': 'Completed', 'startTimeUtc': '2021-05-13T17:55:54.908444Z', 'endTimeUtc': '2021-05-13T18:09:06.484833Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.de66bf8b-fa49-4584-9184-d1c676565692/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=0ZKAMTfpw19E5yAewHDNOnh9BNqj6J3TmIdReqOtZKc%3D&st=2021-05-13T17%3A46%3A16Z&se=2021-05-14T01%3A56%3A16Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.de66bf8b-fa49-4584-9184-d1c676565692/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=MzRefTsQAQX3mQf4N5MgnRMqVtTaEBHBjr6DpGU8CvM%3D&st=2021-05-13T17%3A46%3A16Z&se=2021-05-14T01%3A56%3A16Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlops3730696013.blob.core.windows.net/azureml/ExperimentRun/dcid.de66bf8b-fa49-4584-9184-d1c676565692/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=bApGiEw54%2Bsp8zkxdX7XSkjt5c2WR64TfH1%2B5l7szcc%3D&st=2021-05-13T17%3A46%3A16Z&se=2021-05-14T01%3A56%3A16Z&sp=r'}, 'submittedBy': 'Dave Wentzel'}
# 'Finished'

# %%
# Print the model name, version, tag, and properties
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# driver_model version: 2
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 2
#
#
# driver_model version: 1
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 1
#
#
# compliance-classifier version: 17
# 	 type : classification
# 	 run_id : 0767a613-e8c2-4811-ae6b-64369e340725
# 	 build_number : 20201217.1
#
#
# BikeBuyer.mml version: 4
#
#
# AutoMLb9be0a22f28 version: 1
#
#
# compliance-classifier version: 16
# 	 type : classification
# 	 run_id : a7eb32c9-3207-4a2c-865a-d65fba7946ba
# 	 build_number : 20201119.1
#
#
# compliance-classifier version: 15
# 	 type : classification
# 	 run_id : 8e84d5f5-54c9-48c9-b733-9bbbcd86558b
# 	 build_number : 20201118.1
#
#
# IBM_attrition_model version: 1
# 	 area : HR
# 	 type : attrition
#
#
# AutoML015fd913221 version: 1
#
#
# diabetes_model version: 1
# 	 Training context : Inline Training
# 	 AUC : 0.8857431111811085
# 	 Accuracy : 0.9002222222222223
#
#
# glove-text-classifier version: 1
# 	 type : classification
# 	 run_id : glove-embeddings-classifier_1597854176_900c5cea
#
#
# compliance-classifier version: 14
# 	 type : classification
# 	 run_id : 3886cc4f-8a9d-4608-abea-c588a9074912
# 	 build_number : 20200428.2
#
#
# compliance-classifier version: 13
# 	 type : classification
# 	 run_id : 36b88b87-4c5e-4d64-8fa3-ae721eda608d
# 	 build_number : 20200428.1
#
#
# compliance-classifier version: 12
# 	 type : classification
# 	 run_id : 46b16ce1-7719-4faa-84ae-6d6a4835da08
# 	 build_number : 20200427.1
#
#
# compliance-classifier-qvc version: 1
# 	 type : classification
# 	 run_id : deep-learning-qvc_1587989276_00ba8da2
#
#
# BikeBuyer.mml version: 3
#
#
# compliance-classifier version: 11
# 	 type : classification
# 	 run_id : 8c546c17-d0a9-43dc-92c6-c464fdfe68e2
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 10
# 	 type : classification
# 	 run_id : 3d1df6b1-fd5e-42e1-9021-44038a2aeabd
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 9
# 	 type : classification
# 	 run_id : 22e820b2-1015-4ac2-88d4-c80eed9e0006
# 	 build_number : 20200109.1
#
#
# compliance-classifier version: 8
# 	 type : classification
# 	 run_id : 1d751a7d-5470-473a-8e9b-5b22be5fb2bb
# 	 build_number : 20191028.1
#
#
# compliance-classifier version: 7
# 	 type : classification
# 	 run_id : db72b465-9ae9-4e22-8a3c-22b81e09478b
# 	 build_number : 20191025.1
#
#
# compliance-classifier version: 6
# 	 type : classification
# 	 run_id : 5c59dcd9-f23b-4abf-a1b5-af151927f0e7
# 	 build_number : 20191024.4
#
#
# compliance-classifier version: 5
# 	 type : classification
# 	 run_id : 5c7a146e-bb1a-40a8-a3a0-ac1f953205f4
# 	 build_number : 20191024.3
#
#
# compliance-classifier version: 4
# 	 type : classification
# 	 run_id : 1a7ba8f6-f615-4ec2-8c1f-6926c2517234
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 3
# 	 type : classification
# 	 run_id : 138fdae4-b92f-494d-8d63-ed884f655332
# 	 build_number : 20191024.2
#
#
# compliance-classifier version: 2
#
#
# compliance-classifier version: 1
# 	 type : classification
# 	 run_id : deep-learning_1571935012_a8c321f6
#
#
# BikeBuyer.mml version: 2
#
#
# BikeBuyer.mml version: 1
